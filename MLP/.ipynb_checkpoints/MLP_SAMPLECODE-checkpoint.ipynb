# %% [markdown]
# # 트레이닝 코드

# %% [markdown]
# - 네트워크 구성 및 weight 초기화 함수
#
#
# 파이썬 리스트로 MLP 네트워크 구성 (Weight(가중치)를 리스트로 표현한것)

# %%
#Training
import math
import random
random.seed(1) #Random을 사용했지만 무작위로 나오지 않게 잡아줌

def MLP2(Input, hidden, output):  # 네트워크 구성 및 weight 초기화
    net = list()
    h_layer = [[random.random() for i in range(Input + 1)] for i in range(hidden)]
    net.append(h_layer)
    o_layer = [[random.random() for i in range(hidden + 1)] for i in range(output)]
    net.append(o_layer)
    return net

# %%
from pprint import pprint
net = MLP2(2, 2, 2) #인풋을 2개, 은닉노드 2개, 아웃풋 2개

pprint(net)
print()
pprint(net[0])
print()
pprint(net[0][0])
#가중치가 3개인 이유는 2개는 히든노드에 대한 웨이트이고, 나머지 1개는 바이어스에 대한 웨이트임.(여기서 바이어스에 대한 웨이트는 1을 입력으로 받음)
# Out:
# [[[0.13436424411240122, 0.8474337369372327, 0.763774618976614],
#   [0.2550690257394217, 0.49543508709194095, 0.4494910647887381]],
#  [[0.651592972722763, 0.7887233511355132, 0.0938595867742349],
#   [0.02834747652200631, 0.8357651039198697, 0.43276706790505337]]]
#
# [[0.13436424411240122, 0.8474337369372327, 0.763774618976614],
#  [0.2550690257394217, 0.49543508709194095, 0.4494910647887381]]
#
# [0.13436424411240122, 0.8474337369372327, 0.763774618976614]

# %% [markdown]
# - 시그모이드 함수(활성함수)

# %%
#시그모이드함수 -> 출력값을 이진값만으로 반환. 0이냐 1이냐 둘중하나
def Act_sigmoid(x):  # 활성화 함수 - 시그모이드 
    y = 1 / (1 + math.exp(-x))
    return y

# %% [markdown]
# - Weight값 통합 함수

# %%
def Weight_summation(data, net, layer):
    # 입력값에 layer를 사용한 이유는 히든층에서의 웨이트 계산할 때는 [0]네트워크(웨이트)
    #  아웃층에서 웨이트 계산할 때는 [1]네트워크(웨이트) 사용
    numberOfinp = len(net[0][0]) - 1  # 만약 인풋이 두개면 2
    numberOfhid = len(net[0])  # 히든노드 두개면 2
    numberOfout = len(net[1])  # 아웃노드 두개면 2
    W_s = []  # 웨이트 써메이션 초기화

    if layer == 'H':  # 인풋- > '히든'레이어 갈 때
        for i in range(0, numberOfhid):
            h_w = 0
            h_w = h_w + (1 * net[0][i][numberOfinp])  # 바이어스와 웨이트의 곱 (바이어스노드에 들어오는 입력 값 = 1)
            for j in range(0, numberOfinp):
                h_w = h_w + (data[j] * net[0][i][j])
            W_s.append(h_w)
        W_s = [W_s]

    if layer == 'O':
        for i in range(0, numberOfout):
            o_w = 0
            o_w = o_w + (1 * net[1][i][numberOfhid])
            for j in range(0, numberOfhid):
                o_w = o_w + data[j] * net[1][i][j]  # 히든노드
            W_s.append(o_w)
        W_s = [W_s]  # [ [ ~~ ]]
    return W_s

# %% [markdown]
# - 순방향 전파 함수

# %%
def Forward_propagation(data, net):  # 순전파 진행하면서 인풋데이타, 인풋-히든 웨이트
    node = list()
    node.append(data)
    Ws1 = Weight_summation(data, net, 'H')  # [[ h1_1_before,  h1_2_before ]]
    # print('[[h1_1_before,  h1_2_before]] : ',Ws1,'\n')
    numberOfhid = len(net[0])  # 히든노드 두개면 2
    numberOfout = len(net[1])

    H1 = list()
    for i in range(0, numberOfhid):
        H1.append(Act_sigmoid(Ws1[0][i]))
    # H1 = [ H1_1 H1_2 ~~~~]
    node.append(H1)

    Ws2 = Weight_summation(H1, net, 'O')  # [[ o1_1_before, o_2_before ]]
    # print('[[ o1_1_before, o_2_before ]] : ',Ws2,'\n')

    O1 = list()
    for i in range(0, numberOfout):
        O1.append(Act_sigmoid(Ws2[0][i]))

    node.append(O1)

    # print("[[IN1,IN2, T], [H1, H2], [OUT1, OUT2]]:",node,'\n')
    return node

# %% [markdown]
# - 역방향 전파 함수

# %%
def Backward_propagation(weight, dataset):  # 역전파
    numberOfout = len(weight[1])  # 아웃노드 두개면 2
    numberOfdata = len(dataset)
    numberOfhid = len(weight[0])
    numberOfinp = len(weight[0][0]) - 1

    c2 = list()
    h_layer = [[0 for i in range(numberOfinp + 1)] for i in range(numberOfhid)]
    c2.append(h_layer)
    o_layer = [[0 for i in range(numberOfhid + 1)] for i in range(numberOfout)]
    c2.append(o_layer)
    c2

    init_back = c2

    for i in range(0, numberOfdata):
        Data = dataset[i]
        forward = Forward_propagation(Data, weight)
        Output = forward[2]
        Hid = forward[1]
        Input = forward[0]

        table = []
        for i in range(0, numberOfout):
            if i == Data[numberOfinp]:
                table.append(1)
            else:
                table.append(0)

        # 아웃에서 히든으로 역전파 과정
        for i in range(0, numberOfout):
            init_back[1][i][numberOfhid] = init_back[1][i][numberOfhid] + \
                                           ((Output[i] - table[i]) * Output[i] * (1 - Output[i]) * 1)
            # print('init_back[1][',i,'][',numberOfhid,']=',init_back[1][i][numberOfhid])

            for j in range(0, numberOfhid):
                init_back[1][i][j] = init_back[1][i][j] + \
                                     (Output[i] - table[i]) * Output[i] * (1 - Output[i]) * Hid[j]

        # 히든에서 인풋으로 역전파 과정
        for i in range(0, numberOfhid):
            for j in range(0, numberOfout):
                init_back[0][i][numberOfinp] = init_back[0][i][numberOfinp] + \
                                               ((Output[j] - table[j]) * Output[j] * (1 - Output[j]) * weight[1][j][i] \
                                                * Hid[i] * (1 - Hid[i]) * 1)  # 히든 -> 바이어스 역전파
                for k in range(0, numberOfinp):
                    init_back[0][i][k] = init_back[0][i][k] + \
                                         ((Output[j] - table[j]) * Output[j] * (1 - Output[j]) * weight[1][j][i] \
                                          * Hid[i] * (1 - Hid[i]) * Input[k])

    for i in range(0, numberOfhid):
        for j in range(0, numberOfinp + 1):
            init_back[0][i][j] = init_back[0][i][j] / numberOfdata

    for i in range(0, numberOfout):
        for j in range(0, numberOfhid + 1):
            init_back[1][i][j] = init_back[1][i][j] / numberOfdata

    return init_back

# %% [markdown]
# - Weight Update 함수

# %%
def Weight_update(backpropa, Now_weight):
    numberOfout = len(Now_weight[1])  # 아웃노드 두개면 2
    numberOfhid = len(Now_weight[0])
    numberOfinp = len(Now_weight[0][0]) - 1

    New_weight = list()
    learning_rate = 0.5

    in_hid_w = Now_weight[0]
    hid_out_w = Now_weight[1]

    out_hid_back = backpropa[1]
    hid_in_back = backpropa[0]

    c2 = list()
    h_layer = [[0 for i in range(numberOfinp + 1)] for i in range(numberOfhid)]
    c2.append(h_layer)
    o_layer = [[0 for i in range(numberOfhid + 1)] for i in range(numberOfout)]
    c2.append(o_layer)

    # inp -> hid 업데이트
    for i in range(0, numberOfhid):
        c2[0][i][numberOfinp] = in_hid_w[i][numberOfinp] \
                                - (hid_in_back[i][numberOfinp] * learning_rate)
        for j in range(0, numberOfinp):
            c2[0][i][j] = in_hid_w[i][j] - (hid_in_back[i][j] * learning_rate)

    # hid -> out 업데이트
    for i in range(0, numberOfout):
        c2[1][i][numberOfhid] = hid_out_w[i][numberOfhid] \
                                - (out_hid_back[i][numberOfhid] * learning_rate)
        for j in range(0, numberOfhid):
            c2[1][i][j] = hid_out_w[i][j] - (out_hid_back[i][j] * learning_rate)

    return c2

# %% [markdown]
# - Epoch(시행횟수) 함수

# %%
def Epoch(dataset, net, N):  # N = 학습횟수

    updatedW = net

    for i in range(0, N):
        bp = Backward_propagation(updatedW, dataset)
        updatedW = Weight_update(bp, updatedW)
        mse = Loss_function(dataset, updatedW)
        print(i + 1, '번 학습함, mse =', mse)
    return updatedW

# %% [markdown]
# - 손실함수

# %%
def Loss_function(dataset, net):  # 손실함수 - MSE(평균 제곱 오차)
    numberOfdata = len(dataset)
    numberOfinp = len(net[0][0]) - 1
    numberOfout = len(net[1])
    mse = 0

    for j in range(0, numberOfdata):
        Data = dataset[j]
        table = []
        for i in range(0, numberOfout):
            if i == Data[numberOfinp]:
                table.append(1)
            else:
                table.append(0)

        Fpropa = Forward_propagation(Data, net)  # 아웃풋 구하기

        for j in range(0, numberOfout):
            mse = mse + (1 / numberOfout) * (Fpropa[2][j] - table[j]) ** 2

    mse = mse / numberOfdata
    return mse

# %% [markdown]
# - Weight 학습

# %%
#데이터셋은 단순히 무작위로 입력하면 안됨.
#예를들어 멍멍 했을때 강아지라는 답을 줘야하는데, 멍멍했는데도 고양이라는 답으로 학습을 시키면 결국 쓸모없는 학습을 하게됨.
#그래서 아래 데이터는 단순 랜덤으로 만든 데이터셋이 아니라, 무언가 0이냐 1이냐를 판단하는 기준이 명확히 드러나있지는 않지만
#보이지 않게 녹아있고 그 녹아있는 것을 우리가 학습시키게 될이라고 출력을 내보내는 입 것임. 따라서 단순히 랜덤수를 학습시키는 것은 무의미함.
#0이라고 출력을 내보내는 입력에 대한 경향성이나 규칙, 1력에 대한 경향성의 차이가 존재해야 비로소
#학습에 의미가 생김.

#아래 데이터셋은 교수님이 주신 데이터셋.
data = [[3.5064385449265267, 2.34547092892632525, 0], [4.384621956392097, 3.4530853889904205, 0],
        [4.841442919897487, 4.02507852317520154, 0], [3.5985868973088437, 4.1621314217538705, 0],
        [2.887219775424049, 3.31523082529190005, 0], [9.79822645535526, 1.1052409596099566, 1],
        [7.8261241795117422, 0.6711054766067182, 1], [2.5026163932400305, 5.800780055043912, 1],
        [5.032436157202415, 8.650625621472184, 1], [4.095084253434162, 7.69104329159447, 1]]

net = MLP2(2, 2, 2)
print('초기 가중치:', net, '\n\n')
updatedW = Epoch(data, net, 10000)
print('\n\n최종 업데이트된 가중치:', updatedW)
# Out:
# 초기 가중치: [[[0.762280082457942, 0.0021060533511106927, 0.4453871940548014], [0.7215400323407826, 0.22876222127045265, 0.9452706955539223]], [[0.9014274576114836, 0.030589983033553536, 0.0254458609934608], [0.5414124727934966, 0.9391491627785106, 0.38120423768821243]]]
#
#
# 1 번 학습함, mse = 0.3337678653665938
# 2 번 학습함, mse = 0.3282444033729558
# 3 번 학습함, mse = 0.32281773811643544
# 4 번 학습함, mse = 0.31750652261037177
# 5 번 학습함, mse = 0.31232654698345635
# 6 번 학습함, mse = 0.30729187644084965
# 7 번 학습함, mse = 0.3024160769269211
# 8 번 학습함, mse = 0.29771325845834046
# 9 번 학습함, mse = 0.29319870872928855
# 10 번 학습함, mse = 0.28888897511833544
# 11 번 학습함, mse = 0.28480136393847255
# 12 번 학습함, mse = 0.28095294053885256
# 13 번 학습함, mse = 0.2773592105440953
# 14 번 학습함, mse = 0.27403272124698075
# 15 번 학습함, mse = 0.2709818301818855
# 16 번 학습함, mse = 0.2682098442573813
# 17 번 학습함, mse = 0.26571465014139056
# 18 번 학습함, mse = 0.2634888577212152
# 19 번 학습함, mse = 0.2615203888165801
# 20 번 학습함, mse = 0.2597933823742586
# 21 번 학습함, mse = 0.25828926327360724
# 22 번 학습함, mse = 0.25698783121908625
# 23 번 학습함, mse = 0.2558682579759549
# 24 번 학습함, mse = 0.2549099222526567
# 25 번 학습함, mse = 0.25409305091066375
# 26 번 학습함, mse = 0.2533991662672051
# 27 번 학습함, mse = 0.2528113597130678
# 28 번 학습함, mse = 0.2523144224218032
# 29 번 학습함, mse = 0.2518948668673663
# 30 번 학습함, mse = 0.25154087085296706
# 31 번 학습함, mse = 0.25124217110434766
# 32 번 학습함, mse = 0.2509899278942016
# 33 번 학습함, mse = 0.2507765767102608
# 34 번 학습함, mse = 0.25059567822074336
# 35 번 학습함, mse = 0.2504417739405663
# 36 번 학습함, mse = 0.25031025206201246
# 37 번 학습함, mse = 0.25019722577810827
# 38 번 학습함, mse = 0.2500994249484504
# 39 번 학습함, mse = 0.2500141009858946
# 40 번 학습함, mse = 0.2499389442455632
# 41 번 학습함, mse = 0.2498720128662272
# 42 번 학습함, mse = 0.2498116718638323
# 43 번 학습함, mse = 0.24975654124492297
# 44 번 학습함, mse = 0.24970545194880162
# 45 번 학습함, mse = 0.2496574085099596
# 46 번 학습함, mse = 0.24961155743540217
# 47 번 학습함, mse = 0.24956716040113935
# 48 번 학습함, mse = 0.24952357147972354
# 49 번 학습함, mse = 0.24948021771126547
# 50 번 학습함, mse = 0.24943658242126426
# 51 번 학습함, mse = 0.24939219076880031
# 52 번 학습함, mse = 0.24934659707815338
# 53 번 학습함, mse = 0.24929937356633497
# 54 번 학습함, mse = 0.24925010012938992
# 55 번 학습함, mse = 0.2491983548929483
# 56 번 학습함, mse = 0.24914370526898516
# 57 번 학습함, mse = 0.2490856992929976
# 58 번 학습함, mse = 0.2490238570462126
# 59 번 학습함, mse = 0.24895766199908995
# 60 번 학습함, mse = 0.2488865521493977
# 61 번 학습함, mse = 0.24880991087616047
# 62 번 학습함, mse = 0.24872705749761437
# 63 번 학습함, mse = 0.248637237617712
# 64 번 학습함, mse = 0.2485396134864128
# 65 번 학습함, mse = 0.24843325480355682
# 66 번 학습함, mse = 0.2483171306896912
# 67 번 학습함, mse = 0.2481901039600761
# 68 번 학습함, mse = 0.24805092940282708
# 69 번 학습함, mse = 0.24789825850581257
# 70 번 학습함, mse = 0.24773065400434965
# 71 번 학습함, mse = 0.24754661868399358
# 72 번 학습함, mse = 0.24734464391470098
# 73 번 학습함, mse = 0.247123284076606
# 74 번 학습함, mse = 0.24688126275351568
# 75 번 학습함, mse = 0.2466176143759277
# 76 번 학습함, mse = 0.24633185968916319
# 77 번 학습함, mse = 0.24602420392005167
# 78 번 학습함, mse = 0.24569573272154094
# 79 번 학습함, mse = 0.24534856513693631
# 80 번 학습함, mse = 0.2449859107868682
# 81 번 학습함, mse = 0.2446119793517192
# 82 번 학습함, mse = 0.24423171286556244
# 83 번 학습함, mse = 0.24385035643341718
# 84 번 학습함, mse = 0.2434729378685973
# 85 번 학습함, mse = 0.24310376654195442
# 86 번 학습함, mse = 0.24274606321207357
# 87 번 학습함, mse = 0.24240179140155246
# 88 번 학습함, mse = 0.24207169675598963
# 89 번 학습함, mse = 0.24175550449555386
# 90 번 학습함, mse = 0.24145219803813123
# 91 번 학습함, mse = 0.24116030621154488
# 92 번 학습함, mse = 0.24087814978776936
# 93 번 학습함, mse = 0.2406040251312644
# 94 번 학습함, mse = 0.24033632365491453
# 95 번 학습함, mse = 0.24007359751580623
# 96 번 학습함, mse = 0.23981458602068334
# 97 번 학습함, mse = 0.23955821650670267
# 98 번 학습함, mse = 0.23930359065024262
# 99 번 학습함, mse = 0.23904996393182093
# 100 번 학습함, mse = 0.23879672318541853
# 101 번 학습함, mse = 0.2385433650567969
# 102 번 학습함, mse = 0.23828947676535833
# 103 번 학습함, mse = 0.23803471967177292
# 104 번 학습함, mse = 0.23777881564505496
# 105 번 학습함, mse = 0.23752153596670608
# 106 번 학습함, mse = 0.2372626924079527
# 107 번 학습함, mse = 0.23700213010189547
# 108 번 학습함, mse = 0.2367397218625628
# 109 번 학습함, mse = 0.23647536365152771
# 110 번 학습함, mse = 0.23620897094535076
# 111 번 학습함, mse = 0.23594047580624058
# 112 번 학습함, mse = 0.23566982450076956
# 113 번 학습함, mse = 0.2353969755464575
# 114 번 학습함, mse = 0.23512189809392234
# 115 번 학습함, mse = 0.2348445705740358
# 116 번 학습함, mse = 0.23456497955619401
# 117 번 학습함, mse = 0.2342831187764507
# 118 번 학습함, mse = 0.2339989883037743
# 119 번 학습함, mse = 0.23371259381982293
# 120 번 학습함, mse = 0.23342394599297425
# 121 번 학습함, mse = 0.23313305993136485
# 122 번 학습함, mse = 0.23283995470272312
# 123 번 학습함, mse = 0.23254465291109208
# 124 번 학습함, mse = 0.23224718032231434
# 125 번 학습함, mse = 0.23194756553153603
# 126 번 학습함, mse = 0.23164583966707983
# 127 번 학습함, mse = 0.23134203612591198
# 128 번 학습함, mse = 0.23103619033663914
# 129 번 학습함, mse = 0.23072833954655464
# 130 번 학습함, mse = 0.2304185226297398
# 131 번 학습함, mse = 0.23010677991363568
# 132 번 학습함, mse = 0.2297931530218448
# 133 번 학습함, mse = 0.2294776847312218
# 134 번 학습함, mse = 0.2291604188415633
# 135 번 학습함, mse = 0.2288414000564277
# 136 번 학습함, mse = 0.22852067387380764
# 137 번 학습함, mse = 0.22819828648553867
# 138 번 학습함, mse = 0.22787428468447496
# 139 번 학습함, mse = 0.2275487157785868
# 140 번 학습함, mse = 0.2272216275112406
# 141 번 학습함, mse = 0.22689306798702188
# 142 번 학습함, mse = 0.22656308560253927
# 143 번 학습함, mse = 0.2262317289817232
# 144 번 학습함, mse = 0.22589904691519305
# 145 번 학습함, mse = 0.22556508830332347
# 146 번 학습함, mse = 0.22522990210268393
# 147 번 학습함, mse = 0.22489353727557254
# 148 번 학습함, mse = 0.22455604274239405
# 149 번 학습함, mse = 0.22421746733666909
# 150 번 학습함, mse = 0.22387785976248392
# 151 번 학습함, mse = 0.22353726855421502
# 152 번 학습함, mse = 0.2231957420383833
# 153 번 학습함, mse = 0.22285332829750765
# 154 번 학습함, mse = 0.22251007513584486
# 155 번 학습함, mse = 0.22216603004691468
# 156 번 학습함, mse = 0.22182124018271798
# 157 번 학습함, mse = 0.2214757523245682
# 158 번 학습함, mse = 0.22112961285546265
# 159 번 학습함, mse = 0.22078286773392614
# 160 번 학습함, mse = 0.22043556246926763
# 161 번 학습함, mse = 0.22008774209819326
# 162 번 학습함, mse = 0.21973945116272384
# 163 번 학습함, mse = 0.21939073368937084
# 164 번 학습함, mse = 0.21904163316952235
# 165 번 학습함, mse = 0.21869219254100075
# 166 번 학습함, mse = 0.2183424541707482
# 167 번 학습함, mse = 0.21799245983860457
# 168 번 학습함, mse = 0.2176422507221388
# 169 번 학습함, mse = 0.21729186738249986
# 170 번 학습함, mse = 0.21694134975125334
# 171 번 학습함, mse = 0.21659073711816895
# 172 번 학습함, mse = 0.21624006811992932
# 173 번 학습함, mse = 0.21588938072972655
# 174 번 학습함, mse = 0.2155387122477183
# 175 번 학습함, mse = 0.21518809929231172
# 176 번 학습함, mse = 0.21483757779224807
# 177 번 학습함, mse = 0.21448718297945843
# 178 번 학습함, mse = 0.2141369493826637
# 179 번 학습함, mse = 0.21378691082169138
# 180 번 학습함, mse = 0.21343710040248384
# 181 번 학습함, mse = 0.21308755051277045
# 182 번 학습함, mse = 0.21273829281838136
# 183 번 학습함, mse = 0.21238935826017613
# 184 번 학습함, mse = 0.21204077705156524
# 185 번 학습함, mse = 0.21169257867660157
# 186 번 학습함, mse = 0.21134479188861852
# 187 번 학습함, mse = 0.21099744470939558
# 188 번 학습함, mse = 0.21065056442882893
# 189 번 학습함, mse = 0.21030417760508907
# 190 번 학습함, mse = 0.2099583100652457
# 191 번 학습함, mse = 0.20961298690634284
# 192 번 학습함, mse = 0.20926823249690668
# 193 번 학습함, mse = 0.20892407047887102
# 194 번 학습함, mse = 0.2085805237699047
# 195 번 학습함, mse = 0.20823761456612805
# 196 번 학습함, mse = 0.2078953643452049
# 197 번 학습함, mse = 0.20755379386979894
# 198 번 학습함, mse = 0.20721292319138462
# 199 번 학습함, mse = 0.20687277165440157
# 200 번 학습함, mse = 0.20653335790074695
# 201 번 학습함, mse = 0.2061946998745972
# 202 번 학습함, mse = 0.20585681482755508
# 203 번 학습함, mse = 0.20551971932411664
# 204 번 학습함, mse = 0.20518342924745786
# 205 번 학습함, mse = 0.20484795980553744
# 206 번 학습함, mse = 0.2045133255375177
# 207 번 학습함, mse = 0.20417954032050548
# 208 번 학습함, mse = 0.20384661737661708
# 209 번 학습함, mse = 0.20351456928037082
# 210 번 학습함, mse = 0.20318340796641765
# 211 번 학습함, mse = 0.20285314473761545
# 212 번 학습함, mse = 0.2025237902734601
# 213 번 학습함, mse = 0.2021953546388851
# 214 번 학습함, mse = 0.20186784729344454
# 215 번 학습함, mse = 0.20154127710089673
# 216 번 학습함, mse = 0.2012156523392063
# 217 번 학습함, mse = 0.20089098071098643
# 218 번 학습함, mse = 0.20056726935440444
# 219 번 학습함, mse = 0.20024452485457495
# 220 번 학습함, mse = 0.19992275325546888
# 221 번 학습함, mse = 0.19960196007236783
# 222 번 학습함, mse = 0.19928215030489543
# 223 번 학습함, mse = 0.19896332845065878
# 224 번 학습함, mse = 0.19864549851953786
# 225 번 학습함, mse = 0.1983286640486589
# 226 번 학습함, mse = 0.19801282811809315
# 227 번 학습함, mse = 0.1976979933673216
# 228 번 학습함, mse = 0.19738416201251005
# 229 번 학습함, mse = 0.19707133586463813
# 230 번 학습함, mse = 0.19675951634852873
# 231 번 학습함, mse = 0.19644870452282398
# 232 번 학습함, mse = 0.19613890110095483
# 233 번 학습함, mse = 0.19583010647315072
# 234 번 학습함, mse = 0.1955223207295355
# 235 번 학습함, mse = 0.19521554368435426
# 236 번 학습함, mse = 0.19490977490137415
# 237 번 학습함, mse = 0.1946050137204981
# 238 번 학습함, mse = 0.1943012592856282
# 239 번 학습함, mse = 0.19399851057380918
# 240 번 학습함, mse = 0.19369676642567682
# 241 번 학습함, mse = 0.1933960255772294
# 242 번 학습함, mse = 0.19309628669292866
# 243 번 학습함, mse = 0.19279754840013014
# 244 번 학습함, mse = 0.19249980932482594
# 245 번 학습함, mse = 0.1922030681286731
# 246 번 학습함, mse = 0.1919073235472594
# 247 번 학습함, mse = 0.19161257442954485
# 248 번 학습함, mse = 0.19131881977839255
# 249 번 학습함, mse = 0.19102605879208046
# 250 번 학습함, mse = 0.19073429090666025
# 251 번 학습함, mse = 0.19044351583900176
# 252 번 학습함, mse = 0.1901537336303284
# 253 번 학습함, mse = 0.18986494469001866
# 254 번 학습함, mse = 0.18957714983941315
# 255 번 학습함, mse = 0.1892903503553271
# 256 번 학습함, mse = 0.1890045480129339
# 257 번 학습함, mse = 0.1887197451276405
# 258 번 학습함, mse = 0.1884359445955393
# 259 번 학습함, mse = 0.18815314993197851
# 260 번 학습함, mse = 0.18787136530775322
# 261 번 학습함, mse = 0.18759059558238453
# 262 번 학습함, mse = 0.1873108463339161
# 263 번 학습함, mse = 0.18703212388463109
# 264 번 학습함, mse = 0.18675443532206454
# 265 번 학습함, mse = 0.18647778851467217
# 266 번 학습함, mse = 0.18620219212150554
# 267 번 학습함, mse = 0.18592765559524843
# 268 번 학습함, mse = 0.18565418917798032
# 269 번 학습함, mse = 0.18538180388906494
# 270 번 학습함, mse = 0.18511051150460206
# 271 번 학습함, mse = 0.18484032452794147
# 272 번 학습함, mse = 0.18457125615083908
# 273 번 학습함, mse = 0.18430332020492582
# 274 번 학습함, mse = 0.1840365311032805
# 275 번 학습함, mse = 0.18377090377202823
# 276 번 학습함, mse = 0.1835064535720357
# 277 번 학습함, mse = 0.18324319621094556
# 278 번 학습함, mse = 0.1829811476459653
# 279 번 학습함, mse = 0.18272032397802346
# 280 번 학습함, mse = 0.18246074133809378
# 281 번 학습함, mse = 0.18220241576669233
# 282 번 학습함, mse = 0.18194536308774015
# 283 번 학습함, mse = 0.18168959877817054
# 284 번 학습함, mse = 0.18143513783482423
# 285 번 학습함, mse = 0.1811819946403211
# 286 번 학습함, mse = 0.18093018282971135
# 287 번 학습함, mse = 0.18067971515978962
# 288 번 학습함, mse = 0.1804306033829963
# 289 번 학습함, mse = 0.1801828581278258
# 290 번 학습함, mse = 0.179936488787614
# 291 번 학습함, mse = 0.17969150341947765
# 292 번 학습함, mse = 0.1794479086550353
# 293 번 학습함, mse = 0.17920570962435106
# 294 번 학습함, mse = 0.17896490989431116
# 295 번 학습함, mse = 0.17872551142237894
# 296 번 학습함, mse = 0.1784875145263864
# 297 번 학습함, mse = 0.17825091787070302
# 298 번 학습함, mse = 0.1780157184688101
# 299 번 학습함, mse = 0.17778191170198546
# 300 번 학습함, mse = 0.17754949135349665
# 301 번 학습함, mse = 0.17731844965741356
# 302 번 학습함, mse = 0.17708877736089043
# 303 번 학습함, mse = 0.17686046379854514
# 304 번 학습함, mse = 0.1766334969773818
# 305 번 학습함, mse = 0.17640786367056854
# 306 번 학습함, mse = 0.17618354951829335
# 307 번 학습함, mse = 0.17596053913388313
# 308 번 학습함, mse = 0.17573881621337845
# 309 번 학습함, mse = 0.1755183636468077
# 310 번 학습함, mse = 0.17529916362949471
# 311 번 학습함, mse = 0.1750811977718563
# 312 번 학습함, mse = 0.1748644472062979
# 313 번 학습함, mse = 0.1746488926899831
# 314 번 학습함, mse = 0.17443451470243937
# 315 번 학습함, mse = 0.1742212935371489
# 316 번 학습함, mse = 0.17400920938646508
# 317 번 학습함, mse = 0.17379824241938074
# 318 번 학습함, mse = 0.17358837285184786
# 319 번 학습함, mse = 0.17337958100951123
# 320 번 학습함, mse = 0.17317184738286498
# 321 번 학습함, mse = 0.17296515267496546
# 322 번 학습함, mse = 0.1727594778419464
# 323 번 학습함, mse = 0.17255480412666596
# 324 번 학습함, mse = 0.1723511130858911
# 325 번 학습함, mse = 0.17214838661147028
# 326 번 학습함, mse = 0.1719466069459869
# 327 번 학습함, mse = 0.17174575669340006
# 328 번 학습함, mse = 0.17154581882519201
# 329 번 학습함, mse = 0.17134677668253245
# 330 번 학습함, mse = 0.17114861397495984
# 331 번 학습함, mse = 0.17095131477605757
# 332 번 학습함, mse = 0.17075486351657576
# 333 번 학습함, mse = 0.17055924497541983
# 334 번 학습함, mse = 0.1703644442688929
# 335 번 학습함, mse = 0.17017044683854543
# 336 번 학습함, mse = 0.16997723843794596
# 337 번 학습함, mse = 0.1697848051186597
# 338 번 학습함, mse = 0.16959313321567965
# 339 번 학습함, mse = 0.16940220933252778
# 340 번 학습함, mse = 0.16921202032621213
# 341 번 학습함, mse = 0.16902255329219737
# 342 번 학습함, mse = 0.16883379554952127
# 343 번 학습함, mse = 0.168645734626165
# 344 번 학습함, mse = 0.1684583582447667
# 345 번 학습함, mse = 0.1682716543087461
# 346 번 학습함, mse = 0.16808561088889454
# 347 번 학습함, mse = 0.16790021621046816
# 348 번 학습함, mse = 0.1677154586408124
# 349 번 학습함, mse = 0.16753132667753196
# 350 번 학습함, mse = 0.1673478089372152
# 351 번 학습함, mse = 0.16716489414471208
# 352 번 학습함, mse = 0.1669825711229594
# 353 번 학습함, mse = 0.1668008287833424
# 354 번 학습함, mse = 0.16661965611657706
# 355 번 학습함, mse = 0.16643904218409575
# 356 번 학습함, mse = 0.16625897610991403
# 357 번 학습함, mse = 0.16607944707295802
# 358 번 학습함, mse = 0.16590044429982742
# 359 번 학습함, mse = 0.1657219570579698
# 360 번 학습함, mse = 0.16554397464924292
# 361 번 학습함, mse = 0.1653664864038381
# 362 번 학습함, mse = 0.16518948167454245
# 363 번 학습함, mse = 0.16501294983131307
# 364 번 학습함, mse = 0.16483688025614213
# 365 번 학습함, mse = 0.16466126233818806
# 366 번 학습함, mse = 0.16448608546915114
# 367 번 학습함, mse = 0.16431133903887157
# 368 번 학습함, mse = 0.16413701243113027
# 369 번 학습함, mse = 0.16396309501963122
# 370 번 학습함, mse = 0.16378957616414763
# 371 번 학습함, mse = 0.16361644520681223
# 372 번 학습함, mse = 0.16344369146853616
# 373 번 학습함, mse = 0.16327130424553882
# 374 번 학습함, mse = 0.1630992728059722
# 375 번 학습함, mse = 0.16292758638662636
# 376 번 학습함, mse = 0.16275623418970026
# 377 번 학습함, mse = 0.16258520537962462
# 378 번 학습함, mse = 0.1624144890799236
# 379 번 학습함, mse = 0.1622440743701023
# 380 번 학습함, mse = 0.16207395028254873
# 381 번 학습함, mse = 0.16190410579943731
# 382 번 학습함, mse = 0.16173452984962322
# 383 번 학습함, mse = 0.16156521130551668
# 384 번 학습함, mse = 0.1613961389799255
# 385 번 학습함, mse = 0.16122730162285598
# 386 번 학습함, mse = 0.16105868791826206
# 387 번 학습함, mse = 0.16089028648073064
# 388 번 학습함, mse = 0.1607220858520954
# 389 번 학습함, mse = 0.1605540744979665
# 390 번 학습함, mse = 0.16038624080416652
# 391 번 학습함, mse = 0.16021857307306353
# 392 번 학습함, mse = 0.16005105951978832
# 393 번 학습함, mse = 0.15988368826832638
# 394 번 학습함, mse = 0.15971644734747356
# 395 번 학습함, mse = 0.15954932468664307
# 396 번 학습함, mse = 0.1593823081115122
# 397 번 학습함, mse = 0.15921538533949686
# 398 번 학습함, mse = 0.15904854397504023
# 399 번 학습함, mse = 0.15888177150470198
# 400 번 학습함, mse = 0.15871505529203403
# 401 번 학습함, mse = 0.15854838257222767
# 402 번 학습함, mse = 0.15838174044651543
# 403 번 학습함, mse = 0.15821511587631126
# 404 번 학습함, mse = 0.1580484956770707
# 405 번 학습함, mse = 0.1578818665118512
# 406 번 학습함, mse = 0.1577152148845528
# 407 번 학습함, mse = 0.1575485271328158
# 408 번 학습함, mse = 0.15738178942055217
# 409 번 학습함, mse = 0.15721498773008571
# 410 번 학습함, mse = 0.15704810785387166
# 411 번 학습함, mse = 0.15688113538576798
# 412 번 학습함, mse = 0.15671405571182428
# 413 번 학습함, mse = 0.1565468540005551
# 414 번 학습함, mse = 0.15637951519265908
# 415 번 학습함, mse = 0.15621202399014303
# 416 번 학습함, mse = 0.15604436484480766
# 417 번 학습함, mse = 0.15587652194604545
# 418 번 학습함, mse = 0.15570847920789896
# 419 번 학습함, mse = 0.1555402202553226
# 420 번 학습함, mse = 0.1553717284095854
# 421 번 학습함, mse = 0.15520298667274654
# 422 번 학습함, mse = 0.15503397771112987
# 423 번 학습함, mse = 0.1548646838377154
# 424 번 학습함, mse = 0.1546950869933601
# 425 번 학습함, mse = 0.15452516872674757
# 426 번 학습함, mse = 0.15435491017296277
# 427 번 학습함, mse = 0.15418429203056988
# 428 번 학습함, mse = 0.15401329453706744
# 429 번 학습함, mse = 0.15384189744257368
# 430 번 학습함, mse = 0.15367007998158605
# 431 번 학습함, mse = 0.15349782084264
# 432 번 학습함, mse = 0.15332509813567236
# 433 번 학습함, mse = 0.15315188935687635
# 434 번 학습함, mse = 0.1529781713508085
# 435 번 학습함, mse = 0.15280392026948492
# 436 번 학습함, mse = 0.15262911152817016
# 437 번 학습함, mse = 0.1524537197575328
# 438 번 학습함, mse = 0.15227771875179838
# 439 번 학습함, mse = 0.1521010814124936
# 440 번 학습함, mse = 0.15192377968731824
# 441 번 학습함, mse = 0.1517457845036337
# 442 번 학습함, mse = 0.1515670656959872
# 443 번 학습함, mse = 0.1513875919270208
# 444 번 학습함, mse = 0.15120733060103117
# 445 번 학습함, mse = 0.15102624776934842
# 446 번 학습함, mse = 0.15084430802659704
# 447 번 학습함, mse = 0.1506614743967726
# 448 번 학습함, mse = 0.1504777082079232
# 449 번 학습함, mse = 0.1502929689540607
# 450 번 학습함, mse = 0.15010721414272843
# 451 번 학습함, mse = 0.14992039912643051
# 452 번 학습함, mse = 0.14973247691586597
# 453 번 학습함, mse = 0.14954339797260624
# 454 번 학습함, mse = 0.14935310997850082
# 455 번 학습함, mse = 0.14916155757867888
# 456 번 학습함, mse = 0.1489686820945293
# 457 번 학습함, mse = 0.148774421202468
# 458 번 학습함, mse = 0.1485787085736276
# 459 번 학습함, mse = 0.1483814734688065
# 460 번 학습함, mse = 0.14818264028207465
# 461 번 학습함, mse = 0.1479821280253112
# 462 번 학습함, mse = 0.1477798497446213
# 463 번 학습함, mse = 0.14757571185799326
# 464 번 학습함, mse = 0.14736961340166171
# 465 번 학습함, mse = 0.1471614451703765
# 466 번 학습함, mse = 0.14695108873405452
# 467 번 학습함, mse = 0.1467384153100217
# 468 번 학습함, mse = 0.14652328446611226
# 469 번 학습함, mse = 0.14630554262514292
# 470 번 학습함, mse = 0.14608502133553966
# 471 번 학습함, mse = 0.14586153526595977
# 472 번 학습함, mse = 0.14563487987336024
# 473 번 학습함, mse = 0.14540482868381785
# 474 번 학습함, mse = 0.14517113011314728
# 475 번 학습함, mse = 0.14493350373957245
# 476 번 학습함, mse = 0.14469163592293027
# 477 번 학습함, mse = 0.14444517464360823
# 478 번 학습함, mse = 0.14419372340914338
# 479 번 학습함, mse = 0.14393683404670127
# 480 번 학습함, mse = 0.14367399816525384
# 481 번 학습함, mse = 0.14340463703234094
# 482 번 학습함, mse = 0.14312808956772866
# 483 번 학습함, mse = 0.14284359811226008
# 484 번 학습함, mse = 0.14255029158912763
# 485 번 학습함, mse = 0.1422471656445337
# 486 번 학습함, mse = 0.14193305934857856
# 487 번 학습함, mse = 0.14160662807668742
# 488 번 학습함, mse = 0.14126631231020562
# 489 번 학습함, mse = 0.1409103023412938
# 490 번 학습함, mse = 0.1405364993116822
# 491 번 학습함, mse = 0.1401424737496565
# 492 번 학습함, mse = 0.13972542390633463
# 493 번 학습함, mse = 0.13928213784441973
# 494 번 학습함, mse = 0.13880896547453586
# 495 번 학습함, mse = 0.13830180952217047
# 496 번 학습함, mse = 0.13775614745472892
# 497 번 학습함, mse = 0.13716709901211507
# 498 번 학습함, mse = 0.13652955493645905
# 499 번 학습함, mse = 0.13583838004737864
# 500 번 학습함, mse = 0.13508869610120375
# 501 번 학습함, mse = 0.13427623585447404
# 502 번 학습함, mse = 0.13339774051702785
# 503 번 학습함, mse = 0.13245135265780766
# 504 번 학습함, mse = 0.13143694287543223
# 505 번 학습함, mse = 0.13035630876431553
# 506 번 학습함, mse = 0.1292132025919827
# 507 번 학습함, mse = 0.12801317613295032
# 508 번 학습함, mse = 0.12676326708122237
# 509 번 학습함, mse = 0.12547157934257983
# 510 번 학습함, mse = 0.12414682142053321
# 511 번 학습함, mse = 0.12279786246000657
# 512 번 학습함, mse = 0.12143334962403296
# 513 번 학습함, mse = 0.12006141069301149
# 514 번 학습함, mse = 0.1186894479964643
# 515 번 학습함, mse = 0.117324017046367
# 516 번 학습함, mse = 0.11597077603501231
# 517 번 학습함, mse = 0.11463448971027276
# 518 번 학습함, mse = 0.11331907157297424
# 519 번 학습함, mse = 0.1120276504812558
# 520 번 학습함, mse = 0.11076265056593296
# 521 번 학습함, mse = 0.10952587620212446
# 522 번 학습함, mse = 0.10831859629275986
# 523 번 학습함, mse = 0.10714162415715003
# 524 번 학습함, mse = 0.10599539086886574
# 525 번 학습함, mse = 0.10488001100461922
# 526 번 학습함, mse = 0.10379534052883144
# 527 번 학습함, mse = 0.10274102702908113
# 528 번 학습함, mse = 0.10171655280876049
# 529 번 학습함, mse = 0.10072127149476476
# 530 번 학습함, mse = 0.09975443887598412
# 531 번 학습함, mse = 0.09881523868666717
# 532 번 학습함, mse = 0.0979028040114356
# 533 번 학습함, mse = 0.09701623493229919
# 534 번 학습함, mse = 0.09615461297329184
# 535 번 학습함, mse = 0.0953170128321716
# 536 번 학습함, mse = 0.094502511825083
# 537 번 학습함, mse = 0.09371019741140099
# 538 번 학습함, mse = 0.09293917311318094
# 539 번 학습함, mse = 0.09218856309700182
# 540 번 학습함, mse = 0.09145751564532448
# 541 번 학습함, mse = 0.0907452057093707
# 542 번 학습함, mse = 0.09005083670541712
# 543 번 학습함, mse = 0.08937364169071074
# 544 번 학습함, mse = 0.08871288403338674
# 545 번 학습함, mse = 0.08806785767227632
# 546 번 학습함, mse = 0.08743788704685165
# 547 번 학습함, mse = 0.08682232676435388
# 548 번 학습함, mse = 0.08622056106001277
# 549 번 학습함, mse = 0.08563200309688354
# 550 번 학습함, mse = 0.08505609414392246
# 551 번 학습함, mse = 0.08449230266427077
# 552 번 학습함, mse = 0.08394012334012071
# 553 번 학습함, mse = 0.08339907605583025
# 554 번 학습함, mse = 0.08286870485700024
# 555 번 학습함, mse = 0.08234857689990766
# 556 번 학습함, mse = 0.08183828140290329
# 557 번 학습함, mse = 0.08133742860905109
# 558 번 학습함, mse = 0.08084564876733355
# 559 번 학습함, mse = 0.08036259113812044
# 560 번 학습함, mse = 0.07988792302724076
# 561 번 학습함, mse = 0.07942132885187148
# 562 번 학습함, mse = 0.07896250924052377
# 563 번 학습함, mse = 0.07851118016864013
# 564 번 학습함, mse = 0.07806707213068324
# 565 번 학습함, mse = 0.07762992934908616
# 566 번 학습함, mse = 0.07719950902001535
# 567 번 학습함, mse = 0.07677558059556698
# 568 번 학습함, mse = 0.07635792510175168
# 569 번 학습함, mse = 0.07594633449141695
# 570 번 학습함, mse = 0.07554061103110048
# 571 번 학습함, mse = 0.07514056672068885
# 572 번 학습함, mse = 0.07474602274467372
# 573 번 학습함, mse = 0.07435680895374175
# 574 번 학습함, mse = 0.07397276337540074
# 575 번 학습함, mse = 0.07359373175233164
# 576 번 학습함, mse = 0.0732195671071551
# 577 번 학습함, mse = 0.07285012933231574
# 578 번 학습함, mse = 0.0724852848038083
# 579 번 학습함, mse = 0.07212490601750168
# 580 번 학습함, mse = 0.07176887124685147
# 581 번 학습함, mse = 0.07141706422083147
# 582 번 학습함, mse = 0.0710693738209596
# 583 번 학습함, mse = 0.07072569379633749
# 584 번 학습함, mse = 0.07038592249566962
# 585 번 학습함, mse = 0.07004996261527643
# 586 번 학습함, mse = 0.06971772096216115
# 587 번 학습함, mse = 0.06938910823123777
# 588 번 학습함, mse = 0.06906403879587406
# 589 번 학습함, mse = 0.0687424305109466
# 590 번 학습함, mse = 0.06842420452765031
# 591 번 학습함, mse = 0.06810928511934544
# 592 번 학습함, mse = 0.06779759951776697
# 593 번 학습함, mse = 0.06748907775895835
# 594 번 학습함, mse = 0.0671836525383315
# 595 번 학습함, mse = 0.06688125907428695
# 596 번 학습함, mse = 0.06658183497986524
# 597 번 학습함, mse = 0.06628532014193017
# 598 번 학습함, mse = 0.06599165660741661
# 599 번 학습함, mse = 0.06570078847620318
# 600 번 학습함, mse = 0.06541266180019818
# 601 번 학습함, mse = 0.06512722448825232
# 602 번 학습함, mse = 0.06484442621653609
# 603 번 학습함, mse = 0.06456421834404279
# 604 번 학습함, mse = 0.06428655383289905
# 605 번 학습함, mse = 0.06401138717318525
# 606 번 학습함, mse = 0.06373867431198722
# 607 번 학습함, mse = 0.06346837258641794
# 608 번 학습함, mse = 0.06320044066036545
# 609 번 학습함, mse = 0.06293483846473752
# 610 번 학습함, mse = 0.06267152714098985
# 611 번 학습함, mse = 0.06241046898773678
# 612 번 학습함, mse = 0.0621516274102575
# 613 번 학습함, mse = 0.061894966872721946
# 614 번 학습함, mse = 0.06164045285297243
# 615 번 학습함, mse = 0.06138805179970701
# 616 번 학습함, mse = 0.061137731091920756
# 617 번 학습함, mse = 0.06088945900047045
# 618 번 학습함, mse = 0.06064320465163631
# 619 번 학습함, mse = 0.060398937992562685
# 620 번 학습함, mse = 0.06015662975846747
# 621 번 학습함, mse = 0.05991625144151615
# 622 번 학습함, mse = 0.05967777526126383
# 623 번 학습함, mse = 0.05944117413657442
# 624 번 학습함, mse = 0.05920642165893133
# 625 번 학습함, mse = 0.058973492067060505
# 626 번 학습함, mse = 0.05874236022279039
# 627 번 학습함, mse = 0.05851300158807893
# 628 번 학습함, mse = 0.05828539220314194
# 629 번 학습함, mse = 0.058059508665620554
# 630 번 학습함, mse = 0.0578353281107308
# 631 번 학습함, mse = 0.05761282819233974
# 632 번 학습함, mse = 0.05739198706491814
# 633 번 학습함, mse = 0.05717278336632141
# 634 번 학습함, mse = 0.05695519620135334
# 635 번 학습함, mse = 0.056739205126071314
# 636 번 학습함, mse = 0.05652479013279218
# 637 번 학습함, mse = 0.05631193163576244
# 638 번 학습함, mse = 0.05610061045745664
# 639 번 학습함, mse = 0.05589080781547172
# 640 번 학습함, mse = 0.05568250530998575
# 641 번 학습함, mse = 0.055475684911752
# 642 번 학습함, mse = 0.0552703289506005
# 643 번 학습함, mse = 0.05506642010442162
# 644 번 학습함, mse = 0.054863941388606854
# 645 번 학습함, mse = 0.054662876145923564
# 646 번 학습함, mse = 0.05446320803680268
# 647 번 학습함, mse = 0.05426492103001803
# 648 번 학습함, mse = 0.054067999393738554
# 649 번 학습함, mse = 0.05387242768693497
# 650 번 학습함, mse = 0.053678190751123456
# 651 번 학습함, mse = 0.0534852737024306
# 652 번 학습함, mse = 0.0532936619239636
# 653 번 학습함, mse = 0.05310334105847185
# 654 번 학습함, mse = 0.05291429700128569
# 655 번 학습함, mse = 0.052726515893519524
# 656 번 학습함, mse = 0.05253998411552715
# 657 번 학습함, mse = 0.05235468828059747
# 658 번 학습함, mse = 0.052170615228879835
# 659 번 학습함, mse = 0.051987752021528146
# 660 번 학습함, mse = 0.051806085935054515
# 661 번 학습함, mse = 0.05162560445588253
# 662 번 학습함, mse = 0.05144629527509178
# 663 번 학습함, mse = 0.05126814628334451
# 664 번 학습함, mse = 0.05109114556598754
# 665 번 학습함, mse = 0.05091528139832062
# 666 번 학습함, mse = 0.05074054224102516
# 667 번 학습함, mse = 0.05056691673574557
# 668 번 학습함, mse = 0.0503943937008177
# 669 번 학습함, mse = 0.05022296212713725
# 670 번 학습함, mse = 0.05005261117416293
# 671 번 학습함, mse = 0.049883330166048845
# 672 번 학습함, mse = 0.04971510858790022
# 673 번 학습함, mse = 0.049547936082148206
# 674 번 학습함, mse = 0.04938180244503827
# 675 번 학습함, mse = 0.04921669762322818
# 676 번 학습함, mse = 0.04905261171049087
# 677 번 학습함, mse = 0.048889534944518045
# 678 번 학습함, mse = 0.04872745770382108
# 679 번 학습함, mse = 0.04856637050472458
# 680 번 학습함, mse = 0.04840626399844986
# 681 번 학습함, mse = 0.048247128968284404
# 682 번 학습함, mse = 0.04808895632683432
# 683 번 학습함, mse = 0.04793173711335626
# 684 번 학습함, mse = 0.047775462491166584
# 685 번 학습함, mse = 0.047620123745123984
# 686 번 학습함, mse = 0.0474657122791836
# 687 번 학습함, mse = 0.04731221961401973
# 688 번 학습함, mse = 0.047159637384714466
# 689 번 학습함, mse = 0.047007957338510396
# 690 번 학습함, mse = 0.0468571713326245
# 691 번 학습함, mse = 0.04670727133212159
# 692 번 학습함, mse = 0.046558249407844754
# 693 번 학습함, mse = 0.04641009773440108
# 694 번 학습함, mse = 0.046262808588201
# 695 번 학습함, mse = 0.04611637434554856
# 696 번 학습함, mse = 0.04597078748078197
# 697 번 학습함, mse = 0.04582604056446187
# 698 번 학습함, mse = 0.045682126261606074
# 699 번 학습함, mse = 0.04553903732996939
# 700 번 학습함, mse = 0.045396766618366655
# 701 번 학습함, mse = 0.04525530706503788
# 702 번 학습함, mse = 0.04511465169605386
# 703 번 학습함, mse = 0.04497479362376124
# 704 번 학습함, mse = 0.044835726045265624
# 705 번 학습함, mse = 0.04469744224095134
# 706 번 학습함, mse = 0.044559935573037036
# 707 번 학습함, mse = 0.04442319948416572
# 708 번 학습함, mse = 0.04428722749602841
# 709 번 학습함, mse = 0.04415201320802006
# 710 번 학습함, mse = 0.044017550295926876
# 711 번 학습함, mse = 0.0438838325106444
# 712 번 학습함, mse = 0.04375085367692475
# 713 번 학습함, mse = 0.04361860769215293
# 714 번 학습함, mse = 0.04348708852515058
# 715 번 학습함, mse = 0.043356290215006914
# 716 번 학습함, mse = 0.04322620686993584
# 717 번 학습함, mse = 0.0430968326661584
# 718 번 학습함, mse = 0.04296816184681005
# 719 번 학습함, mse = 0.0428401887208717
# 720 번 학습함, mse = 0.04271290766212428
# 721 번 학습함, mse = 0.04258631310812568
# 722 번 학습함, mse = 0.042460399559209924
# 723 번 학습함, mse = 0.04233516157750747
# 724 번 학습함, mse = 0.04221059378598651
# 725 번 학습함, mse = 0.042086690867514306
# 726 번 학습함, mse = 0.04196344756393814
# 727 번 학습함, mse = 0.0418408586751856
# 728 번 학습함, mse = 0.0417189190583832
# 729 번 학습함, mse = 0.04159762362699321
# 730 번 학습함, mse = 0.041476967349968
# 731 번 학습함, mse = 0.04135694525092179
# 732 번 학습함, mse = 0.04123755240731854
# 733 번 학습함, mse = 0.04111878394967672
# 734 번 학습함, mse = 0.041000635060789443
# 735 번 학습함, mse = 0.04088310097496018
# 736 번 학습함, mse = 0.04076617697725351
# 737 번 학습함, mse = 0.04064985840276042
# 738 번 학습함, mse = 0.0405341406358779
# 739 번 학습함, mse = 0.04041901910960243
# 740 번 학습함, mse = 0.040304489304837106
# 741 번 학습함, mse = 0.040190546749711745
# 742 번 학습함, mse = 0.04007718701891615
# 743 번 학습함, mse = 0.03996440573304573
# 744 번 학습함, mse = 0.03985219855795954
# 745 번 학습함, mse = 0.03974056120415008
# 746 번 학습함, mse = 0.039629489426125014
# 747 번 학습함, mse = 0.03951897902180007
# 748 번 학습함, mse = 0.03940902583190317
# 749 번 학습함, mse = 0.039299625739389374
# 750 번 학습함, mse = 0.03919077466886642
# 751 번 학습함, mse = 0.03908246858603067
# 752 번 학습함, mse = 0.038974703497113045
# 753 번 학습함, mse = 0.03886747544833497
# 754 번 학습함, mse = 0.0387607805253739
# 755 번 학습함, mse = 0.038654614852838186
# 756 번 학습함, mse = 0.03854897459375142
# 757 번 학습함, mse = 0.038443855949045355
# 758 번 학습함, mse = 0.03833925515706209
# 759 번 학습함, mse = 0.0382351684930645
# 760 번 학습함, mse = 0.038131592268755274
# 761 번 학습함, mse = 0.038028522831804065
# 762 번 학습함, mse = 0.037925956565382744
# 763 번 학습함, mse = 0.0378238898877086
# 764 번 학습함, mse = 0.03772231925159497
# 765 번 학습함, mse = 0.03762124114400972
# 766 번 학습함, mse = 0.03752065208564085
# 767 번 학습함, mse = 0.03742054863046941
# 768 번 학습함, mse = 0.037320927365349574
# 769 번 학습함, mse = 0.0372217849095953
# 770 번 학습함, mse = 0.037123117914574136
# 771 번 학습함, mse = 0.03702492306330736
# 772 번 학습함, mse = 0.03692719707007676
# 773 번 학습함, mse = 0.03682993668003766
# 774 번 학습함, mse = 0.03673313866883822
# 775 번 학습함, mse = 0.03663679984224481
# 776 번 학습함, mse = 0.03654091703577333
# 777 번 학습함, mse = 0.03644548711432634
# 778 번 학습함, mse = 0.036350506971836095
# 779 번 학습함, mse = 0.03625597353091288
# 780 번 학습함, mse = 0.03616188374249908
# 781 번 학습함, mse = 0.036068234585528616
# 782 번 학습함, mse = 0.03597502306659148
# 783 번 학습함, mse = 0.03588224621960373
# 784 번 학습함, mse = 0.03578990110548227
# 785 번 학습함, mse = 0.035697984811824804
# 786 번 학습함, mse = 0.035606494452594624
# 787 번 학습함, mse = 0.03551542716781002
# 788 번 학습함, mse = 0.035424780123238755
# 789 번 학습함, mse = 0.03533455051009665
# 790 번 학습함, mse = 0.03524473554475112
# 791 번 학습함, mse = 0.03515533246842892
# 792 번 학습함, mse = 0.03506633854692816
# 793 번 학습함, mse = 0.034977751070334843
# 794 번 학습함, mse = 0.03488956735274336
# 795 번 학습함, mse = 0.03480178473198121
# 796 번 학습함, mse = 0.0347144005693376
# 797 번 학습함, mse = 0.034627412249296295
# 798 번 학습함, mse = 0.034540817179271946
# 799 번 학습함, mse = 0.034454612789350636
# 800 번 학습함, mse = 0.03436879653203378
# 801 번 학습함, mse = 0.03428336588198607
# 802 번 학습함, mse = 0.03419831833578678
# 803 번 학습함, mse = 0.03411365141168466
# 804 번 학습함, mse = 0.03402936264935632
# 805 번 학습함, mse = 0.03394544960966811
# 806 번 학습함, mse = 0.03386190987444122
# 807 번 학습함, mse = 0.03377874104622024
# 808 번 학습함, mse = 0.03369594074804471
# 809 번 학습함, mse = 0.03361350662322417
# 810 번 학습함, mse = 0.033531436335116044
# 811 번 학습함, mse = 0.03344972756690685
# 812 번 학습함, mse = 0.03336837802139616
# 813 번 학습함, mse = 0.03328738542078378
# 814 번 학습함, mse = 0.0332067475064597
# 815 번 학습함, mse = 0.03312646203879696
# 816 번 학습함, mse = 0.03304652679694729
# 817 번 학습함, mse = 0.03296693957863962
# 818 번 학습함, mse = 0.03288769819998109
# 819 번 학습함, mse = 0.0328088004952611
# 820 번 학습함, mse = 0.03273024431675765
# 821 번 학습함, mse = 0.03265202753454641
# 822 번 학습함, mse = 0.03257414803631233
# 823 번 학습함, mse = 0.032496603727163814
# 824 번 학습함, mse = 0.0324193925294492
# 825 번 학습함, mse = 0.03234251238257576
# 826 번 학습함, mse = 0.032265961242831195
# 827 번 학습함, mse = 0.03218973708320717
# 828 번 학습함, mse = 0.03211383789322552
# 829 번 학습함, mse = 0.03203826167876632
# 830 번 학습함, mse = 0.031963006461898626
# 831 번 학습함, mse = 0.03188807028071307
# 832 번 학습함, mse = 0.031813451189156725
# 833 번 학습함, mse = 0.031739147256870166
# 834 번 학습함, mse = 0.03166515656902651
# 835 번 학습함, mse = 0.031591477226172546
# 836 번 학습함, mse = 0.03151810734407203
# 837 번 학습함, mse = 0.03144504505355068
# 838 번 학습함, mse = 0.031372288500343445
# 839 번 학습함, mse = 0.03129983584494352
# 840 번 학습함, mse = 0.031227685262453286
# 841 번 학습함, mse = 0.03115583494243715
# 842 번 학습함, mse = 0.03108428308877631
# 843 번 학습함, mse = 0.03101302791952517
# 844 번 학습함, mse = 0.03094206766676958
# 845 번 학습함, mse = 0.030871400576487018
# 846 번 학습함, mse = 0.03080102490840824
# 847 번 학습함, mse = 0.030730938935880876
# 848 번 학습함, mse = 0.03066114094573444
# 849 번 학습함, mse = 0.0305916292381473
# 850 번 학습함, mse = 0.030522402126515042
# 851 번 학습함, mse = 0.030453457937320582
# 852 번 학습함, mse = 0.03038479501000576
# 853 번 학습함, mse = 0.03031641169684456
# 854 번 학습함, mse = 0.0302483063628178
# 855 번 학습함, mse = 0.030180477385489412
# 856 번 학습함, mse = 0.030112923154884265
# 857 번 학습함, mse = 0.03004564207336715
# 858 번 학습함, mse = 0.029978632555523653
# 859 번 학습함, mse = 0.029911893028042084
# 860 번 학습함, mse = 0.029845421929597066
# 861 번 학습함, mse = 0.029779217710734267
# 862 번 학습함, mse = 0.029713278833756778
# 863 번 학습함, mse = 0.02964760377261259
# 864 번 학습함, mse = 0.029582191012783515
# 865 번 학습함, mse = 0.029517039051175403
# 866 번 학습함, mse = 0.029452146396009644
# 867 번 학습함, mse = 0.02938751156671592
# 868 번 학습함, mse = 0.029323133093826177
# 869 번 학습함, mse = 0.02925900951886994
# 870 번 학습함, mse = 0.02919513939427077
# 871 번 학습함, mse = 0.029131521283243856
# 872 번 학습함, mse = 0.029068153759694938
# 873 번 학습함, mse = 0.029005035408120328
# 874 번 학습함, mse = 0.02894216482350793
# 875 번 학습함, mse = 0.028879540611239717
# 876 번 학습함, mse = 0.028817161386995017
# 877 번 학습함, mse = 0.028755025776655063
# 878 번 학습함, mse = 0.028693132416208612
# 879 번 학습함, mse = 0.028631479951658528
# 880 번 학습함, mse = 0.02857006703892966
# 881 번 학습함, mse = 0.02850889234377743
# 882 번 학습함, mse = 0.028447954541697813
# 883 번 학습함, mse = 0.028387252317838008
# 884 번 학습함, mse = 0.028326784366908293
# 885 번 학습함, mse = 0.028266549393094826
# 886 번 학습함, mse = 0.028206546109973474
# 887 번 학습함, mse = 0.028146773240424444
# 888 번 학습함, mse = 0.028087229516548025
# 889 번 학습함, mse = 0.028027913679581174
# 890 번 학습함, mse = 0.027968824479815087
# 891 번 학습함, mse = 0.027909960676513617
# 892 번 학습함, mse = 0.02785132103783265
# 893 번 학습함, mse = 0.02779290434074026
# 894 번 학습함, mse = 0.027734709370937922
# 895 번 학습함, mse = 0.027676734922782376
# 896 번 학습함, mse = 0.027618979799208566
# 897 번 학습함, mse = 0.027561442811653125
# 898 번 학습함, mse = 0.027504122779979052
# 899 번 학습함, mse = 0.027447018532400884
# 900 번 학습함, mse = 0.02739012890541087
# 901 번 학습함, mse = 0.027333452743705893
# 902 번 학습함, mse = 0.02727698890011505
# 903 번 학습함, mse = 0.027220736235528335
# 904 번 학습함, mse = 0.02716469361882572
# 905 번 학습함, mse = 0.02710885992680718
# 906 번 학습함, mse = 0.027053234044123436
# 907 번 학습함, mse = 0.026997814863207504
# 908 번 학습함, mse = 0.026942601284206835
# 909 번 학습함, mse = 0.026887592214916267
# 910 번 학습함, mse = 0.026832786570711625
# 911 번 학습함, mse = 0.02677818327448415
# 912 번 학습함, mse = 0.026723781256575457
# 913 번 학습함, mse = 0.02666957945471326
# 914 번 학습함, mse = 0.026615576813947755
# 915 번 학습함, mse = 0.02656177228658871
# 916 번 학습함, mse = 0.02650816483214314
# 917 번 학습함, mse = 0.026454753417253684
# 918 번 학습함, mse = 0.026401537015637588
# 919 번 학습함, mse = 0.02634851460802639
# 920 번 학습함, mse = 0.026295685182106114
# 921 번 학습함, mse = 0.026243047732458204
# 922 번 학습함, mse = 0.026190601260500972
# 923 번 학습함, mse = 0.02613834477443173
# 924 번 학습함, mse = 0.02608627728916944
# 925 번 학습함, mse = 0.026034397826297954
# 926 번 학습함, mse = 0.02598270541401005
# 927 번 학습함, mse = 0.02593119908705156
# 928 번 학습함, mse = 0.025879877886666663
# 929 번 학습함, mse = 0.02582874086054323
# 930 번 학습함, mse = 0.025777787062759034
# 931 번 학습함, mse = 0.025727015553728395
# 932 번 학습함, mse = 0.025676425400149326
# 933 번 학습함, mse = 0.025626015674951298
# 934 번 학습함, mse = 0.02557578545724351
# 935 번 학습함, mse = 0.02552573383226358
# 936 번 학습함, mse = 0.02547585989132692
# 937 번 학습함, mse = 0.025426162731776523
# 938 번 학습함, mse = 0.025376641456933163
# 939 번 학습함, mse = 0.025327295176046316
# 940 번 학습함, mse = 0.025278123004245385
# 941 번 학습함, mse = 0.02522912406249143
# 942 번 학습함, mse = 0.025180297477529468
# 943 번 학습함, mse = 0.025131642381841186
# 944 번 학습함, mse = 0.025083157913598088
# 945 번 학습함, mse = 0.0250348432166152
# 946 번 학습함, mse = 0.02498669744030508
# 947 번 학습함, mse = 0.024938719739632513
# 948 번 학습함, mse = 0.024890909275069355
# 949 번 학습함, mse = 0.024843265212550102
# 950 번 학습함, mse = 0.024795786723427686
# 951 번 학습함, mse = 0.02474847298442984
# 952 번 학습함, mse = 0.024701323177615746
# 953 번 학습함, mse = 0.02465433649033329
# 954 번 학습함, mse = 0.02460751211517655
# 955 번 학습함, mse = 0.024560849249943825
# 956 번 학습함, mse = 0.024514347097595986
# 957 번 학습함, mse = 0.024468004866215278
# 958 번 학습함, mse = 0.024421821768964506
# 959 번 학습함, mse = 0.024375797024046623
# 960 번 학습함, mse = 0.024329929854664645
# 961 번 학습함, mse = 0.024284219488982024
# 962 번 학습함, mse = 0.024238665160083453
# 963 번 학습함, mse = 0.024193266105935796
# 964 번 학습함, mse = 0.024148021569349726
# 965 번 학습함, mse = 0.024102930797941454
# 966 번 학습함, mse = 0.02405799304409499
# 967 번 학습함, mse = 0.02401320756492471
# 968 번 학습함, mse = 0.023968573622238167
# 969 번 학습함, mse = 0.02392409048249948
# 970 번 학습함, mse = 0.0238797574167929
# 971 번 학습함, mse = 0.0238355737007867
# 972 번 학습함, mse = 0.023791538614697544
# 973 번 학습함, mse = 0.023747651443255097
# 974 번 학습함, mse = 0.023703911475666962
# 975 번 학습함, mse = 0.023660318005583953
# 976 번 학습함, mse = 0.023616870331065708
# 977 번 학습함, mse = 0.023573567754546693
# 978 번 학습함, mse = 0.0235304095828023
# 979 번 학습함, mse = 0.023487395126915542
# 980 번 학습함, mse = 0.023444523702243862
# 981 번 학습함, mse = 0.023401794628386274
# 982 번 학습함, mse = 0.023359207229150906
# 983 번 학습함, mse = 0.023316760832522748
# 984 번 학습함, mse = 0.023274454770631742
# 985 번 학습함, mse = 0.023232288379721074
# 986 번 학습함, mse = 0.023190261000115946
# 987 번 학습함, mse = 0.02314837197619245
# 988 번 학습함, mse = 0.023106620656346808
# 989 번 학습함, mse = 0.02306500639296485
# 990 번 학습함, mse = 0.023023528542391918
# 991 번 학습함, mse = 0.022982186464902757
# 992 번 학습함, mse = 0.02294097952467197
# 993 번 학습함, mse = 0.022899907089744594
# 994 번 학습함, mse = 0.022858968532006967
# 995 번 학습함, mse = 0.022818163227157802
# 996 번 학습함, mse = 0.022777490554679695
# 997 번 학습함, mse = 0.02273694989781065
# 998 번 학습함, mse = 0.02269654064351611
# 999 번 학습함, mse = 0.02265626218246099
# 1000 번 학습함, mse = 0.022616113908982168
# 1001 번 학습함, mse = 0.022576095221061097
# 1002 번 학습함, mse = 0.022536205520296754
# 1003 번 학습함, mse = 0.022496444211878696
# 1004 번 학습함, mse = 0.02245681070456052
# 1005 번 학습함, mse = 0.022417304410633457
# 1006 번 학습함, mse = 0.022377924745900172
# 1007 번 학습함, mse = 0.022338671129648893
# 1008 번 학습함, mse = 0.022299542984627746
# 1009 번 학습함, mse = 0.022260539737019237
# 1010 번 학습함, mse = 0.02222166081641504
# 1011 번 학습함, mse = 0.022182905655790962
# 1012 번 학습함, mse = 0.02214427369148223
# 1013 번 학습함, mse = 0.02210576436315878
# 1014 번 학습함, mse = 0.022067377113801016
# 1015 번 학습함, mse = 0.022029111389675567
# 1016 번 학습함, mse = 0.021990966640311436
# 1017 번 학습함, mse = 0.021952942318476214
# 1018 번 학습함, mse = 0.02191503788015257
# 1019 번 학습함, mse = 0.021877252784514946
# 1020 번 학습함, mse = 0.02183958649390643
# 1021 번 학습함, mse = 0.021802038473815837
# 1022 번 학습함, mse = 0.02176460819285502
# 1023 번 학습함, mse = 0.02172729512273635
# 1024 번 학습함, mse = 0.021690098738250303
# 1025 번 학습함, mse = 0.021653018517243484
# 1026 번 학습함, mse = 0.02161605394059657
# 1027 번 학습함, mse = 0.021579204492202568
# 1028 번 학습함, mse = 0.02154246965894528
# 1029 번 학습함, mse = 0.0215058489306779
# 1030 번 학습함, mse = 0.02146934180020187
# 1031 번 학습함, mse = 0.021432947763245766
# 1032 번 학습함, mse = 0.02139666631844451
# 1033 번 학습함, mse = 0.021360496967318725
# 1034 번 학습함, mse = 0.021324439214254254
# 1035 번 학습함, mse = 0.02128849256648179
# 1036 번 학습함, mse = 0.021252656534056787
# 1037 번 학습함, mse = 0.02121693062983948
# 1038 번 학습함, mse = 0.021181314369475113
# 1039 번 학습함, mse = 0.02114580727137421
# 1040 번 학습함, mse = 0.021110408856693248
# 1041 번 학습함, mse = 0.021075118649315234
# 1042 번 학습함, mse = 0.021039936175830637
# 1043 번 학습함, mse = 0.021004860965518356
# 1044 번 학습함, mse = 0.020969892550326965
# 1045 번 학습함, mse = 0.020935030464855956
# 1046 번 학습함, mse = 0.02090027424633733
# 1047 번 학습함, mse = 0.020865623434617158
# 1048 번 학습함, mse = 0.02083107757213745
# 1049 번 학습함, mse = 0.020796636203918063
# 1050 번 학습함, mse = 0.02076229887753881
# 1051 번 학습함, mse = 0.020728065143121727
# 1052 번 학습함, mse = 0.020693934553313448
# 1053 번 학습함, mse = 0.02065990666326773
# 1054 번 학습함, mse = 0.020625981030628206
# 1055 번 학습함, mse = 0.020592157215511157
# 1056 번 학습함, mse = 0.02055843478048848
# 1057 번 학습함, mse = 0.02052481329057083
# 1058 번 학습함, mse = 0.020491292313190874
# 1059 번 학습함, mse = 0.02045787141818662
# 1060 번 학습함, mse = 0.020424550177785005
# 1061 번 학습함, mse = 0.0203913281665855
# 1062 번 학습함, mse = 0.020358204961543964
# 1063 번 학습함, mse = 0.020325180141956507
# 1064 번 학습함, mse = 0.020292253289443556
# 1065 번 학습함, mse = 0.020259423987934087
# 1066 번 학습함, mse = 0.02022669182364986
# 1067 번 학습함, mse = 0.02019405638508991
# 1068 번 학습함, mse = 0.020161517263015113
# 1069 번 학습함, mse = 0.020129074050432866
# 1070 번 학습함, mse = 0.020096726342581885
# 1071 번 학습함, mse = 0.020064473736917166
# 1072 번 학습함, mse = 0.02003231583309501
# 1073 번 학습함, mse = 0.02000025223295826
# 1074 번 학습함, mse = 0.019968282540521534
# 1075 번 학습함, mse = 0.019936406361956698
# 1076 번 학습함, mse = 0.019904623305578323
# 1077 번 학습함, mse = 0.0198729329818294
# 1078 번 학습함, mse = 0.019841335003267103
# 1079 번 학습함, mse = 0.019809828984548607
# 1080 번 학습함, mse = 0.01977841454241714
# 1081 번 학습함, mse = 0.019747091295688
# 1082 번 학습함, mse = 0.01971585886523489
# 1083 번 학습함, mse = 0.019684716873976126
# 1084 번 학습함, mse = 0.01965366494686111
# 1085 번 학습함, mse = 0.019622702710856876
# 1086 번 학습함, mse = 0.019591829794934696
# 1087 번 학습함, mse = 0.019561045830056863
# 1088 번 학습함, mse = 0.01953035044916353
# 1089 번 학습함, mse = 0.019499743287159654
# 1090 번 학습함, mse = 0.019469223980902083
# 1091 번 학습함, mse = 0.01943879216918669
# 1092 번 학습함, mse = 0.019408447492735625
# 1093 번 학습함, mse = 0.019378189594184702
# 1094 번 학습함, mse = 0.019348018118070843
# 1095 번 학습함, mse = 0.019317932710819653
# 1096 번 학습함, mse = 0.019287933020733047
# 1097 번 학습함, mse = 0.019258018697976984
# 1098 번 학습함, mse = 0.01922818939456939
# 1099 번 학습함, mse = 0.019198444764368033
# 1100 번 학습함, mse = 0.019168784463058548
# 1101 번 학습함, mse = 0.019139208148142597
# 1102 번 학습함, mse = 0.019109715478926075
# 1103 번 학습함, mse = 0.01908030611650745
# 1104 번 학습함, mse = 0.019050979723766095
# 1105 번 학습함, mse = 0.019021735965350804
# 1106 번 학습함, mse = 0.018992574507668426
# 1107 번 학습함, mse = 0.018963495018872425
# 1108 번 학습함, mse = 0.018934497168851757
# 1109 번 학습함, mse = 0.018905580629219577
# 1110 번 학습함, mse = 0.018876745073302274
# 1111 번 학습함, mse = 0.0188479901761284
# 1112 번 학습함, mse = 0.01881931561441781
# 1113 번 학습함, mse = 0.018790721066570815
# 1114 번 학습함, mse = 0.018762206212657482
# 1115 번 학습함, mse = 0.01873377073440688
# 1116 번 학습함, mse = 0.01870541431519661
# 1117 번 학습함, mse = 0.01867713664004222
# 1118 번 학습함, mse = 0.018648937395586866
# 1119 번 학습함, mse = 0.018620816270090892
# 1120 번 학습함, mse = 0.01859277295342161
# 1121 번 학습함, mse = 0.018564807137043143
# 1122 번 학습함, mse = 0.018536918514006222
# 1123 번 학습함, mse = 0.01850910677893829
# 1124 번 학습함, mse = 0.018481371628033417
# 1125 번 학습함, mse = 0.0184537127590425
# 1126 번 학습함, mse = 0.01842612987126341
# 1127 번 학습함, mse = 0.01839862266553131
# 1128 번 학습함, mse = 0.018371190844208938
# 1129 번 학습함, mse = 0.01834383411117705
# 1130 번 학습함, mse = 0.018316552171824894
# 1131 번 학습함, mse = 0.018289344733040776
# 1132 번 학습함, mse = 0.01826221150320267
# 1133 번 학습함, mse = 0.018235152192168907
# 1134 번 학습함, mse = 0.01820816651126897
# 1135 번 학습함, mse = 0.018181254173294265
# 1136 번 학습함, mse = 0.01815441489248911
# 1137 번 학습함, mse = 0.018127648384541624
# 1138 번 학습함, mse = 0.0181009543665748
# 1139 번 학습함, mse = 0.01807433255713757
# 1140 번 학습함, mse = 0.01804778267619604
# 1141 번 학습함, mse = 0.018021304445124654
# 1142 번 학습함, mse = 0.017994897586697495
# 1143 번 학습함, mse = 0.017968561825079693
# 1144 번 학습함, mse = 0.01794229688581878
# 1145 번 학습함, mse = 0.017916102495836264
# 1146 번 학습함, mse = 0.017889978383419082
# 1147 번 학습함, mse = 0.017863924278211273
# 1148 번 학습함, mse = 0.017837939911205625
# 1149 번 학습함, mse = 0.017812025014735413
# 1150 번 학습함, mse = 0.01778617932246619
# 1151 번 학습함, mse = 0.017760402569387667
# 1152 번 학습함, mse = 0.017734694491805536
# 1153 번 학습함, mse = 0.017709054827333558
# 1154 번 학습함, mse = 0.0176834833148855
# 1155 번 학습함, mse = 0.01765797969466729
# 1156 번 학습함, mse = 0.01763254370816909
# 1157 번 학습함, mse = 0.017607175098157547
# 1158 번 학습함, mse = 0.017581873608668048
# 1159 번 학습함, mse = 0.017556638984996986
# 1160 번 학습함, mse = 0.01753147097369421
# 1161 번 학습함, mse = 0.017506369322555337
# 1162 번 학습함, mse = 0.017481333780614335
# 1163 번 학습함, mse = 0.017456364098135998
# 1164 번 학습함, mse = 0.017431460026608545
# 1165 번 학습함, mse = 0.01740662131873621
# 1166 번 학습함, mse = 0.017381847728432067
# 1167 번 학습함, mse = 0.017357139010810582
# 1168 번 학습함, mse = 0.017332494922180565
# 1169 번 학습함, mse = 0.017307915220037964
# 1170 번 학습함, mse = 0.017283399663058724
# 1171 번 학습함, mse = 0.01725894801109177
# 1172 번 학습함, mse = 0.017234560025151995
# 1173 번 학습함, mse = 0.017210235467413345
# 1174 번 학습함, mse = 0.01718597410120184
# 1175 번 학습함, mse = 0.017161775690988788
# 1176 번 학습함, mse = 0.01713764000238392
# 1177 번 학습함, mse = 0.0171135668021287
# 1178 번 학습함, mse = 0.01708955585808953
# 1179 번 학습함, mse = 0.01706560693925118
# 1180 번 학습함, mse = 0.017041719815710076
# 1181 번 학습함, mse = 0.01701789425866782
# 1182 번 학습함, mse = 0.016994130040424577
# 1183 번 학습함, mse = 0.01697042693437268
# 1184 번 학습함, mse = 0.01694678471499014
# 1185 번 학습함, mse = 0.016923203157834295
# 1186 번 학습함, mse = 0.01689968203953541
# 1187 번 학습함, mse = 0.016876221137790463
# 1188 번 학습함, mse = 0.016852820231356792
# 1189 번 학습함, mse = 0.016829479100045997
# 1190 번 학습함, mse = 0.016806197524717646
# 1191 번 학습함, mse = 0.016782975287273263
# 1192 번 학습함, mse = 0.016759812170650156
# 1193 번 학습함, mse = 0.016736707958815412
# 1194 번 학습함, mse = 0.016713662436759966
# 1195 번 학습함, mse = 0.016690675390492484
# 1196 번 학습함, mse = 0.016667746607033608
# 1197 번 학습함, mse = 0.016644875874409985
# 1198 번 학습함, mse = 0.01662206298164848
# 1199 번 학습함, mse = 0.016599307718770294
# 1200 번 학습함, mse = 0.01657660987678538
# 1201 번 학습함, mse = 0.01655396924768654
# 1202 번 학습함, mse = 0.016531385624443895
# 1203 번 학습함, mse = 0.01650885880099911
# 1204 번 학습함, mse = 0.016486388572259925
# 1205 번 학습함, mse = 0.016463974734094527
# 1206 번 학습함, mse = 0.01644161708332604
# 1207 번 학습함, mse = 0.01641931541772703
# 1208 번 학습함, mse = 0.01639706953601407
# 1209 번 학습함, mse = 0.016374879237842345
# 1210 번 학습함, mse = 0.016352744323800232
# 1211 번 학습함, mse = 0.01633066459540403
# 1212 번 학습함, mse = 0.016308639855092573
# 1213 번 학습함, mse = 0.016286669906222052
# 1214 번 학습함, mse = 0.01626475455306074
# 1215 번 학습함, mse = 0.016242893600783778
# 1216 번 학습함, mse = 0.016221086855468088
# 1217 번 학습함, mse = 0.01619933412408715
# 1218 번 학습함, mse = 0.016177635214506044
# 1219 번 학습함, mse = 0.016155989935476248
# 1220 번 학습함, mse = 0.016134398096630705
# 1221 번 학습함, mse = 0.016112859508478843
# 1222 번 학습함, mse = 0.016091373982401576
# 1223 번 학습함, mse = 0.016069941330646396
# 1224 번 학습함, mse = 0.01604856136632253
# 1225 번 학습함, mse = 0.016027233903396013
# 1226 번 학습함, mse = 0.016005958756684913
# 1227 번 학습함, mse = 0.015984735741854515
# 1228 번 학습함, mse = 0.0159635646754126
# 1229 번 학습함, mse = 0.01594244537470469
# 1230 번 학습함, mse = 0.015921377657909356
# 1231 번 학습함, mse = 0.015900361344033546
# 1232 번 학습함, mse = 0.015879396252907987
# 1233 번 학습함, mse = 0.015858482205182524
# 1234 번 학습함, mse = 0.015837619022321597
# 1235 번 학습함, mse = 0.0158168065265997
# 1236 번 학습함, mse = 0.01579604454109684
# 1237 번 학습함, mse = 0.01577533288969407
# 1238 번 학습함, mse = 0.01575467139706905
# 1239 번 학습함, mse = 0.015734059888691598
# 1240 번 학습함, mse = 0.0157134981908193
# 1241 번 학습함, mse = 0.0156929861304932
# 1242 번 학습함, mse = 0.015672523535533365
# 1243 번 학습함, mse = 0.015652110234534673
# 1244 번 학습함, mse = 0.015631746056862475
# 1245 번 학습함, mse = 0.015611430832648366
# 1246 번 학습함, mse = 0.015591164392785952
# 1247 번 학습함, mse = 0.015570946568926668
# 1248 번 학습함, mse = 0.015550777193475607
# 1249 번 학습함, mse = 0.015530656099587346
# 1250 번 학습함, mse = 0.015510583121161898
# 1251 번 학습함, mse = 0.015490558092840567
# 1252 번 학습함, mse = 0.015470580850001895
# 1253 번 학습함, mse = 0.015450651228757656
# 1254 번 학습함, mse = 0.015430769065948837
# 1255 번 학습함, mse = 0.015410934199141612
# 1256 번 학습함, mse = 0.01539114646662348
# 1257 번 학습함, mse = 0.01537140570739923
# 1258 번 학습함, mse = 0.01535171176118709
# 1259 번 학습함, mse = 0.015332064468414886
# 1260 번 학습함, mse = 0.015312463670216058
# 1261 번 학습함, mse = 0.015292909208425996
# 1262 번 학습함, mse = 0.01527340092557809
# 1263 번 학습함, mse = 0.015253938664900041
# 1264 번 학습함, mse = 0.01523452227031007
# 1265 번 학습함, mse = 0.015215151586413154
# 1266 번 학습함, mse = 0.015195826458497416
# 1267 번 학습함, mse = 0.015176546732530318
# 1268 번 학습함, mse = 0.015157312255155073
# 1269 번 학습함, mse = 0.015138122873686996
# 1270 번 학습함, mse = 0.015118978436109884
# 1271 번 학습함, mse = 0.01509987879107239
# 1272 번 학습함, mse = 0.015080823787884539
# 1273 번 학습함, mse = 0.015061813276514097
# 1274 번 학습함, mse = 0.015042847107583088
# 1275 번 학습함, mse = 0.015023925132364275
# 1276 번 학습함, mse = 0.015005047202777722
# 1277 번 학습함, mse = 0.014986213171387264
# 1278 번 학습함, mse = 0.01496742289139714
# 1279 번 학습함, mse = 0.014948676216648535
# 1280 번 학습함, mse = 0.014929973001616224
# 1281 번 학습함, mse = 0.014911313101405168
# ...
# 9606 번 학습함, mse = 0.00112569926773497
# 9607 번 학습함, mse = 0.0011255685650038312
# 9608 번 학습함, mse = 0.0011254378920529493
# 9609 번 학습함, mse = 0.0011253072488722423
# 9610 번 학습함, mse = 0.0011251766354516378
# 9611 번 학습함, mse = 0.0011250460517810688
# 9612 번 학습함, mse = 0.0011249154978504716
# 9613 번 학습함, mse = 0.0011247849736497808
# 9614 번 학습함, mse = 0.0011246544791689464
# 9615 번 학습함, mse = 0.0011245240143979173
# 9616 번 학습함, mse = 0.0011243935793266442
# 9617 번 학습함, mse = 0.0011242631739450883
# 9618 번 학습함, mse = 0.0011241327982432089
# 9619 번 학습함, mse = 0.0011240024522109762
# 9620 번 학습함, mse = 0.0011238721358383624
# 9621 번 학습함, mse = 0.0011237418491153394
# 9622 번 학습함, mse = 0.0011236115920318919
# 9623 번 학습함, mse = 0.0011234813645780027
# 9624 번 학습함, mse = 0.001123351166743664
# 9625 번 학습함, mse = 0.001123220998518867
# 9626 번 학습함, mse = 0.0011230908598936127
# 9627 번 학습함, mse = 0.0011229607508579005
# 9628 번 학습함, mse = 0.0011228306714017432
# 9629 번 학습함, mse = 0.0011227006215151476
# 9630 번 학습함, mse = 0.0011225706011881342
# 9631 번 학습함, mse = 0.0011224406104107213
# 9632 번 학습함, mse = 0.0011223106491729375
# 9633 번 학습함, mse = 0.0011221807174648067
# 9634 번 학습함, mse = 0.0011220508152763704
# 9635 번 학습함, mse = 0.00112192094259766
# 9636 번 학습함, mse = 0.0011217910994187272
# 9637 번 학습함, mse = 0.001121661285729611
# 9638 번 학습함, mse = 0.0011215315015203704
# 9639 번 학습함, mse = 0.001121401746781058
# 9640 번 학습함, mse = 0.0011212720215017344
# 9641 번 학습함, mse = 0.001121142325672468
# 9642 번 학습함, mse = 0.001121012659283328
# 9643 번 학습함, mse = 0.001120883022324387
# 9644 번 학습함, mse = 0.001120753414785724
# 9645 번 학습함, mse = 0.0011206238366574233
# 9646 번 학습함, mse = 0.0011204942879295729
# 9647 번 학습함, mse = 0.0011203647685922636
# 9648 번 학습함, mse = 0.001120235278635592
# 9649 번 학습함, mse = 0.0011201058180496598
# 9650 번 학습함, mse = 0.0011199763868245725
# 9651 번 학습함, mse = 0.0011198469849504375
# 9652 번 학습함, mse = 0.0011197176124173702
# 9653 번 학습함, mse = 0.001119588269215491
# 9654 번 학습함, mse = 0.0011194589553349208
# 9655 번 학습함, mse = 0.0011193296707657885
# 9656 번 학습함, mse = 0.0011192004154982214
# 9657 번 학습함, mse = 0.001119071189522361
# 9658 번 학습함, mse = 0.001118941992828347
# 9659 번 학습함, mse = 0.0011188128254063217
# 9660 번 학습함, mse = 0.0011186836872464367
# 9661 번 학습함, mse = 0.0011185545783388446
# 9662 번 학습함, mse = 0.0011184254986737062
# 9663 번 학습함, mse = 0.0011182964482411794
# 9664 번 학습함, mse = 0.0011181674270314343
# 9665 번 학습함, mse = 0.0011180384350346411
# 9666 번 학습함, mse = 0.0011179094722409766
# 9667 번 학습함, mse = 0.0011177805386406196
# 9668 번 학습함, mse = 0.0011176516342237548
# 9669 번 학습함, mse = 0.0011175227589805717
# 9670 번 학습함, mse = 0.0011173939129012615
# 9671 번 학습함, mse = 0.0011172650959760258
# 9672 번 학습함, mse = 0.0011171363081950623
# 9673 번 학습함, mse = 0.0011170075495485785
# 9674 번 학습함, mse = 0.0011168788200267843
# 9675 번 학습함, mse = 0.0011167501196198987
# 9676 번 학습함, mse = 0.0011166214483181345
# 9677 번 학습함, mse = 0.001116492806111719
# 9678 번 학습함, mse = 0.0011163641929908814
# 9679 번 학습함, mse = 0.0011162356089458527
# 9680 번 학습함, mse = 0.0011161070539668695
# 9681 번 학습함, mse = 0.0011159785280441738
# 9682 번 학습함, mse = 0.0011158500311680094
# 9683 번 학습함, mse = 0.0011157215633286273
# 9684 번 학습함, mse = 0.0011155931245162823
# 9685 번 학습함, mse = 0.0011154647147212302
# 9686 번 학습함, mse = 0.001115336333933735
# 9687 번 학습함, mse = 0.0011152079821440653
# 9688 번 학습함, mse = 0.0011150796593424914
# 9689 번 학습함, mse = 0.001114951365519288
# 9690 번 학습함, mse = 0.0011148231006647374
# 9691 번 학습함, mse = 0.0011146948647691214
# 9692 번 학습함, mse = 0.0011145666578227303
# 9693 번 학습함, mse = 0.001114438479815856
# 9694 번 학습함, mse = 0.0011143103307387971
# 9695 번 학습함, mse = 0.0011141822105818543
# 9696 번 학습함, mse = 0.0011140541193353337
# 9697 번 학습함, mse = 0.001113926056989545
# 9698 번 학습함, mse = 0.0011137980235348065
# 9699 번 학습함, mse = 0.0011136700189614322
# 9700 번 학습함, mse = 0.0011135420432597488
# 9701 번 학습함, mse = 0.0011134140964200784
# 9702 번 학습함, mse = 0.0011132861784327573
# 9703 번 학습함, mse = 0.0011131582892881225
# 9704 번 학습함, mse = 0.0011130304289765109
# 9705 번 학습함, mse = 0.0011129025974882677
# 9706 번 학습함, mse = 0.0011127747948137424
# 9707 번 학습함, mse = 0.0011126470209432923
# 9708 번 학습함, mse = 0.0011125192758672676
# 9709 번 학습함, mse = 0.0011123915595760336
# 9710 번 학습함, mse = 0.0011122638720599562
# 9711 번 학습함, mse = 0.0011121362133094063
# 9712 번 학습함, mse = 0.0011120085833147544
# 9713 번 학습함, mse = 0.0011118809820663854
# 9714 번 학습함, mse = 0.0011117534095546806
# 9715 번 학습함, mse = 0.0011116258657700249
# 9716 번 학습함, mse = 0.0011114983507028089
# 9717 번 학습함, mse = 0.0011113708643434327
# 9718 번 학습함, mse = 0.0011112434066822938
# 9719 번 학습함, mse = 0.0011111159777097957
# 9720 번 학습함, mse = 0.0011109885774163526
# 9721 번 학습함, mse = 0.0011108612057923698
# 9722 번 학습함, mse = 0.0011107338628282692
# 9723 번 학습함, mse = 0.0011106065485144694
# 9724 번 학습함, mse = 0.0011104792628413977
# 9725 번 학습함, mse = 0.001110352005799485
# 9726 번 학습함, mse = 0.0011102247773791638
# 9727 번 학습함, mse = 0.0011100975775708705
# 9728 번 학습함, mse = 0.0011099704063650497
# 9729 번 학습함, mse = 0.0011098432637521496
# 9730 번 학습함, mse = 0.0011097161497226169
# 9731 번 학습함, mse = 0.0011095890642669126
# 9732 번 학습함, mse = 0.0011094620073754907
# 9733 번 학습함, mse = 0.0011093349790388188
# 9734 번 학습함, mse = 0.0011092079792473625
# 9735 번 학습함, mse = 0.0011090810079915957
# 9736 번 학습함, mse = 0.0011089540652619919
# 9737 번 학습함, mse = 0.0011088271510490322
# 9738 번 학습함, mse = 0.0011087002653432036
# 9739 번 학습함, mse = 0.0011085734081349953
# 9740 번 학습함, mse = 0.0011084465794148973
# 9741 번 학습함, mse = 0.0011083197791734104
# 9742 번 학습함, mse = 0.001108193007401032
# 9743 번 학습함, mse = 0.0011080662640882686
# 9744 번 학습함, mse = 0.0011079395492256357
# 9745 번 학습함, mse = 0.0011078128628036386
# 9746 번 학습함, mse = 0.0011076862048128057
# 9747 번 학습함, mse = 0.0011075595752436502
# 9748 번 학습함, mse = 0.0011074329740867034
# 9749 번 학습함, mse = 0.001107306401332496
# 9750 번 학습함, mse = 0.0011071798569715634
# 9751 번 학습함, mse = 0.0011070533409944419
# 9752 번 학습함, mse = 0.0011069268533916762
# 9753 번 학습함, mse = 0.0011068003941538183
# 9754 번 학습함, mse = 0.0011066739632714134
# 9755 번 학습함, mse = 0.0011065475607350214
# 9756 번 학습함, mse = 0.0011064211865352007
# 9757 번 학습함, mse = 0.001106294840662517
# 9758 번 학습함, mse = 0.001106168523107537
# 9759 번 학습함, mse = 0.001106042233860833
# 9760 번 학습함, mse = 0.0011059159729129835
# 9761 번 학습함, mse = 0.0011057897402545693
# 9762 번 학습함, mse = 0.0011056635358761748
# 9763 번 학습함, mse = 0.0011055373597683882
# 9764 번 학습함, mse = 0.0011054112119218034
# 9765 번 학습함, mse = 0.001105285092327021
# 9766 번 학습함, mse = 0.0011051590009746354
# 9767 번 학습함, mse = 0.0011050329378552608
# 9768 번 학습함, mse = 0.001104906902959501
# 9769 번 학습함, mse = 0.001104780896277972
# 9770 번 학습함, mse = 0.001104654917801293
# 9771 번 학습함, mse = 0.0011045289675200866
# 9772 번 학습함, mse = 0.0011044030454249777
# 9773 번 학습함, mse = 0.0011042771515065966
# 9774 번 학습함, mse = 0.0011041512857555788
# 9775 번 학습함, mse = 0.0011040254481625628
# 9776 번 학습함, mse = 0.0011038996387181914
# 9777 번 학습함, mse = 0.0011037738574131133
# 9778 번 학습함, mse = 0.0011036481042379785
# 9779 번 학습함, mse = 0.0011035223791834418
# 9780 번 학습함, mse = 0.0011033966822401628
# 9781 번 학습함, mse = 0.0011032710133988056
# 9782 번 학습함, mse = 0.001103145372650037
# 9783 번 학습함, mse = 0.0011030197599845326
# 9784 번 학습함, mse = 0.001102894175392959
# 9785 번 학습함, mse = 0.0011027686188660062
# 9786 번 학습함, mse = 0.0011026430903943534
# 9787 번 학습함, mse = 0.001102517589968688
# 9788 번 학습함, mse = 0.0011023921175797064
# 9789 번 학습함, mse = 0.0011022666732180995
# 9790 번 학습함, mse = 0.0011021412568745735
# 9791 번 학습함, mse = 0.0011020158685398265
# 9792 번 학습함, mse = 0.0011018905082045732
# 9793 번 학습함, mse = 0.001101765175859522
# 9794 번 학습함, mse = 0.0011016398714953917
# 9795 번 학습함, mse = 0.0011015145951029015
# 9796 번 학습함, mse = 0.001101389346672779
# 9797 번 학습함, mse = 0.0011012641261957496
# 9798 번 학습함, mse = 0.0011011389336625522
# 9799 번 학습함, mse = 0.0011010137690639164
# 9800 번 학습함, mse = 0.001100888632390588
# 9801 번 학습함, mse = 0.0011007635236333117
# 9802 번 학습함, mse = 0.0011006384427828361
# 9803 번 학습함, mse = 0.0011005133898299162
# 9804 번 학습함, mse = 0.0011003883647653075
# 9805 번 학습함, mse = 0.001100263367579772
# 9806 번 학습함, mse = 0.001100138398264077
# 9807 번 학습함, mse = 0.0011000134568089882
# 9808 번 학습함, mse = 0.001099888543205283
# 9809 번 학습함, mse = 0.0010997636574437372
# 9810 번 학습함, mse = 0.0010996387995151331
# 9811 번 학습함, mse = 0.0010995139694102577
# 9812 번 학습함, mse = 0.0010993891671198994
# 9813 번 학습함, mse = 0.001099264392634853
# 9814 번 학습함, mse = 0.0010991396459459138
# 9815 번 학습함, mse = 0.0010990149270438858
# 9816 번 학습함, mse = 0.0010988902359195768
# 9817 번 학습함, mse = 0.0010987655725637922
# 9818 번 학습함, mse = 0.0010986409369673521
# 9819 번 학습함, mse = 0.0010985163291210706
# 9820 번 학습함, mse = 0.0010983917490157706
# 9821 번 학습함, mse = 0.0010982671966422775
# 9822 번 학습함, mse = 0.0010981426719914211
# 9823 번 학습함, mse = 0.0010980181750540386
# 9824 번 학습함, mse = 0.0010978937058209637
# 9825 번 학습함, mse = 0.001097769264283043
# 9826 번 학습함, mse = 0.0010976448504311199
# 9827 번 학습함, mse = 0.0010975204642560455
# 9828 번 학습함, mse = 0.0010973961057486746
# 9829 번 학습함, mse = 0.0010972717748998627
# 9830 번 학습함, mse = 0.0010971474717004766
# 9831 번 학습함, mse = 0.001097023196141376
# 9832 번 학습함, mse = 0.0010968989482134392
# 9833 번 학습함, mse = 0.0010967747279075346
# 9834 번 학습함, mse = 0.0010966505352145418
# 9835 번 학습함, mse = 0.0010965263701253412
# 9836 번 학습함, mse = 0.001096402232630826
# 9837 번 학습함, mse = 0.0010962781227218785
# 9838 번 학습함, mse = 0.0010961540403893965
# 9839 번 학습함, mse = 0.0010960299856242763
# 9840 번 학습함, mse = 0.0010959059584174206
# 9841 번 학습함, mse = 0.0010957819587597366
# 9842 번 학습함, mse = 0.0010956579866421338
# 9843 번 학습함, mse = 0.0010955340420555288
# 9844 번 학습함, mse = 0.0010954101249908334
# 9845 번 학습함, mse = 0.001095286235438976
# 9846 번 학습함, mse = 0.0010951623733908781
# 9847 번 학습함, mse = 0.0010950385388374716
# 9848 번 학습함, mse = 0.0010949147317696908
# 9849 번 학습함, mse = 0.001094790952178472
# 9850 번 학습함, mse = 0.001094667200054758
# 9851 번 학습함, mse = 0.0010945434753894935
# 9852 번 학습함, mse = 0.001094419778173631
# 9853 번 학습함, mse = 0.0010942961083981232
# 9854 번 학습함, mse = 0.001094172466053922
# 9855 번 학습함, mse = 0.0010940488511319976
# 9856 번 학습함, mse = 0.00109392526362331
# 9857 번 학습함, mse = 0.001093801703518832
# 9858 번 학습함, mse = 0.001093678170809534
# 9859 번 학습함, mse = 0.0010935546654863946
# 9860 번 학습함, mse = 0.0010934311875403955
# 9861 번 학습함, mse = 0.0010933077369625203
# 9862 번 학습함, mse = 0.001093184313743762
# 9863 번 학습함, mse = 0.0010930609178751087
# 9864 번 학습함, mse = 0.0010929375493475605
# 9865 번 학습함, mse = 0.001092814208152116
# 9866 번 학습함, mse = 0.0010926908942797845
# 9867 번 학습함, mse = 0.0010925676077215693
# 9868 번 학습함, mse = 0.0010924443484684875
# 9869 번 학습함, mse = 0.0010923211165115526
# 9870 번 학습함, mse = 0.0010921979118417864
# 9871 번 학습함, mse = 0.001092074734450214
# 9872 번 학습함, mse = 0.0010919515843278624
# 9873 번 학습함, mse = 0.0010918284614657642
# 9874 번 학습함, mse = 0.001091705365854958
# 9875 번 학습함, mse = 0.0010915822974864793
# 9876 번 학습함, mse = 0.0010914592563513782
# 9877 번 학습함, mse = 0.0010913362424406947
# 9878 번 학습함, mse = 0.0010912132557454879
# 9879 번 학습함, mse = 0.0010910902962568089
# 9880 번 학습함, mse = 0.001090967363965719
# 9881 번 학습함, mse = 0.0010908444588632795
# 9882 번 학습함, mse = 0.0010907215809405643
# 9883 번 학습함, mse = 0.001090598730188636
# 9884 번 학습함, mse = 0.0010904759065985747
# 9885 번 학습함, mse = 0.001090353110161458
# 9886 번 학습함, mse = 0.0010902303408683708
# 9887 번 학습함, mse = 0.0010901075987103971
# 9888 번 학습함, mse = 0.0010899848836786283
# 9889 번 학습함, mse = 0.0010898621957641606
# 9890 번 학습함, mse = 0.0010897395349580893
# 9891 번 학습함, mse = 0.0010896169012515197
# 9892 번 학습함, mse = 0.0010894942946355585
# 9893 번 학습함, mse = 0.0010893717151013124
# 9894 번 학습함, mse = 0.0010892491626398953
# 9895 번 학습함, mse = 0.0010891266372424287
# 9896 번 학습함, mse = 0.0010890041389000319
# 9897 번 학습함, mse = 0.0010888816676038297
# 9898 번 학습함, mse = 0.001088759223344953
# 9899 번 학습함, mse = 0.0010886368061145328
# 9900 번 학습함, mse = 0.0010885144159037087
# 9901 번 학습함, mse = 0.00108839205270362
# 9902 번 학습함, mse = 0.0010882697165054127
# 9903 번 학습함, mse = 0.0010881474073002324
# 9904 번 학습함, mse = 0.001088025125079235
# 9905 번 학습함, mse = 0.001087902869833575
# 9906 번 학습함, mse = 0.0010877806415544125
# 9907 번 학습함, mse = 0.0010876584402329105
# 9908 번 학습함, mse = 0.0010875362658602408
# 9909 번 학습함, mse = 0.0010874141184275712
# 9910 번 학습함, mse = 0.0010872919979260768
# 9911 번 학습함, mse = 0.0010871699043469398
# 9912 번 학습함, mse = 0.0010870478376813423
# 9913 번 학습함, mse = 0.0010869257979204692
# 9914 번 학습함, mse = 0.0010868037850555114
# 9915 번 학습함, mse = 0.0010866817990776677
# 9916 번 학습함, mse = 0.001086559839978131
# 9917 번 학습함, mse = 0.0010864379077481078
# 9918 번 학습함, mse = 0.001086316002378802
# 9919 번 학습함, mse = 0.0010861941238614241
# 9920 번 학습함, mse = 0.0010860722721871851
# 9921 번 학습함, mse = 0.0010859504473473085
# 9922 번 학습함, mse = 0.0010858286493330082
# 9923 번 학습함, mse = 0.001085706878135514
# 9924 번 학습함, mse = 0.0010855851337460564
# 9925 번 학습함, mse = 0.0010854634161558629
# 9926 번 학습함, mse = 0.0010853417253561723
# 9927 번 학습함, mse = 0.0010852200613382245
# 9928 번 학습함, mse = 0.001085098424093265
# 9929 번 학습함, mse = 0.0010849768136125394
# 9930 번 학습함, mse = 0.0010848552298873021
# 9931 번 학습함, mse = 0.0010847336729088064
# 9932 번 학습함, mse = 0.001084612142668313
# 9933 번 학습함, mse = 0.001084490639157084
# 9934 번 학습함, mse = 0.001084369162366386
# 9935 번 학습함, mse = 0.0010842477122874898
# 9936 번 학습함, mse = 0.0010841262889116701
# 9937 번 학습함, mse = 0.0010840048922302046
# 9938 번 학습함, mse = 0.0010838835222343724
# 9939 번 학습함, mse = 0.0010837621789154658
# 9940 번 학습함, mse = 0.0010836408622647694
# 9941 번 학습함, mse = 0.0010835195722735762
# 9942 번 학습함, mse = 0.0010833983089331871
# 9943 번 학습함, mse = 0.0010832770722348994
# 9944 번 학습함, mse = 0.0010831558621700167
# 9945 번 학습함, mse = 0.0010830346787298515
# 9946 번 학습함, mse = 0.001082913521905712
# 9947 번 학습함, mse = 0.0010827923916889145
# 9948 번 학습함, mse = 0.0010826712880707802
# 9949 번 학습함, mse = 0.00108255021104263
# 9950 번 학습함, mse = 0.0010824291605957955
# 9951 번 학습함, mse = 0.001082308136721602
# 9952 번 학습함, mse = 0.0010821871394113883
# 9953 번 학습함, mse = 0.0010820661686564898
# 9954 번 학습함, mse = 0.0010819452244482503
# 9955 번 학습함, mse = 0.0010818243067780152
# 9956 번 학습함, mse = 0.0010817034156371324
# 9957 번 학습함, mse = 0.0010815825510169558
# 9958 번 학습함, mse = 0.0010814617129088445
# 9959 번 학습함, mse = 0.0010813409013041562
# 9960 번 학습함, mse = 0.0010812201161942577
# 9961 번 학습함, mse = 0.0010810993575705165
# 9962 번 학습함, mse = 0.001080978625424302
# 9963 번 학습함, mse = 0.0010808579197469953
# 9964 번 학습함, mse = 0.0010807372405299697
# 9965 번 학습함, mse = 0.0010806165877646125
# 9966 번 학습함, mse = 0.0010804959614423083
# 9967 번 학습함, mse = 0.0010803753615544493
# 9968 번 학습함, mse = 0.0010802547880924278
# 9969 번 학습함, mse = 0.0010801342410476414
# 9970 번 학습함, mse = 0.0010800137204114934
# 9971 번 학습함, mse = 0.0010798932261753887
# 9972 번 학습함, mse = 0.0010797727583307362
# 9973 번 학습함, mse = 0.0010796523168689503
# 9974 번 학습함, mse = 0.0010795319017814441
# 9975 번 학습함, mse = 0.0010794115130596375
# 9976 번 학습함, mse = 0.0010792911506949622
# 9977 번 학습함, mse = 0.0010791708146788326
# 9978 번 학습함, mse = 0.001079050505002692
# 9979 번 학습함, mse = 0.0010789302216579683
# 9980 번 학습함, mse = 0.0010788099646361037
# 9981 번 학습함, mse = 0.0010786897339285385
# 9982 번 학습함, mse = 0.0010785695295267182
# 9983 번 학습함, mse = 0.001078449351422095
# 9984 번 학습함, mse = 0.0010783291996061188
# 9985 번 학습함, mse = 0.0010782090740702494
# 9986 번 학습함, mse = 0.0010780889748059478
# 9987 번 학습함, mse = 0.0010779689018046777
# 9988 번 학습함, mse = 0.0010778488550579042
# 9989 번 학습함, mse = 0.0010777288345571044
# 9990 번 학습함, mse = 0.001077608840293749
# 9991 번 학습함, mse = 0.0010774888722593205
# 9992 번 학습함, mse = 0.0010773689304452976
# 9993 번 학습함, mse = 0.0010772490148431729
# 9994 번 학습함, mse = 0.001077129125444429
# 9995 번 학습함, mse = 0.0010770092622405657
# 9996 번 학습함, mse = 0.0010768894252230767
# 9997 번 학습함, mse = 0.0010767696143834653
# 9998 번 학습함, mse = 0.0010766498297132363
# 9999 번 학습함, mse = 0.0010765300712038944
# 10000 번 학습함, mse = 0.001076410338846958
#
#
# 최종 업데이트된 가중치: [[[4.1420949832869125, -3.1439422237080716, 2.053207587151659], [1.0227003808119506, -3.1849740173116396, -0.3659898981213347]], [[6.914969030301216, -6.892585888743422, -3.3776734299209576], [-6.9145405303614575, 6.892661536140577, 3.3773157954106936]]]

# %%
#TEST
def Predict(data, net):
    numberOfdata = len(data)
    numberOfinp = len(data[0]) - 1
    for i in range(0, numberOfdata):
        Data = data[i]
        print(i + 1, '번째 input:', Forward_propagation(Data, net)[0][0:-1])
        predict_po = Forward_propagation(Data, net)[2]
        print('예측값에 대한 확률:', predict_po)
        predict_va = Predict_value(predict_po)
        print('예측값:', predict_va)
        print('정답:', Data[numberOfinp], '\n')


def Predict_value(pre_output):
    tmp = max(pre_output)
    index = pre_output.index(tmp)
    return index


# 데이타셋
dataset = [[3.5064385449265267, 2.34547092892632525, 0], [4.384621956392097, 3.4530853889904205, 0],
           [4.841442919897487, 4.02507852317520154, 0], [3.5985868973088437, 4.1621314217538705, 0],
           [2.887219775424049, 3.31523082529190005, 0], [9.79822645535526, 1.1052409596099566, 1],
           [7.8261241795117422, 0.6711054766067182, 1], [2.5026163932400305, 5.800780055043912, 1],
           [5.032436157202415, 8.650625621472184, 1], [4.095084253434162, 7.69104329159447, 1]]

# 트레이닝된 Weight값 입력
Final_Weight = [[[4.1420949832869125, -3.1439422237080716, 2.053207587151659], [1.0227003808119506, -3.1849740173116396, -0.3659898981213347]], [[6.914969030301216, -6.892585888743422, -3.3776734299209576], [-6.9145405303614575, 6.892661536140577, 3.3773157954106936]]]
# 예측
Predict(dataset, Final_Weight)
# Out:
# 1 번째 input: [3.5064385449265267, 2.3454709289263254]
# 예측값에 대한 확률: [0.9689220399334668, 0.031080124777117895]
# 예측값: 0
# 정답: 0
#
# 2 번째 input: [4.384621956392097, 3.4530853889904205]
# 예측값에 대한 확률: [0.9715188660810137, 0.028483095955977224]
# 예측값: 0
# 정답: 0
#
# 3 번째 input: [4.841442919897487, 4.0250785231752015]
# 예측값에 대한 확률: [0.9716653003935661, 0.028336650354011596]
# 예측값: 0
# 정답: 0
#
# 4 번째 input: [3.5985868973088437, 4.1621314217538705]
# 예측값에 대한 확률: [0.9675838475306725, 0.032418101661130364]
# 예측값: 0
# 정답: 0
#
# 5 번째 input: [2.887219775424049, 3.3152308252919]
# 예측값에 대한 확률: [0.9660754732919242, 0.03392647276644696]
# 예측값: 0
# 정답: 0
#
# 6 번째 input: [9.79822645535526, 1.1052409596099566]
# 예측값에 대한 확률: [0.03421134832970721, 0.9657934868568566]
# 예측값: 1
# 정답: 1
#
# 7 번째 input: [7.826124179511742, 0.6711054766067182]
# 예측값에 대한 확률: [0.03464822996585227, 0.9653566599279859]
# 예측값: 1
# 정답: 1
#
# 8 번째 input: [2.5026163932400305, 5.800780055043912]
# 예측값에 대한 확률: [0.03366103570026461, 0.9663273705702564]
# 예측값: 1
# 정답: 1
#
# 9 번째 input: [5.032436157202415, 8.650625621472184]
# 예측값에 대한 확률: [0.03608886395733164, 0.9638988929425186]
# 예측값: 1
# 정답: 1
#
# 10 번째 input: [4.095084253434162, 7.69104329159447]
# 예측값에 대한 확률: [0.03427764993378938, 0.9657105900514928]
# 예측값: 1
# 정답: 1

# %%
#ReLu_Training
import math
import random

random.seed(1)


def MLP2(input, hidden, output):  # 네트워크 구성 및 weight 초기화
    net = list()
    h_layer = [[random.random() for i in range(input + 1)] for i in range(hidden)]
    net.append(h_layer)
    o_layer = [[random.random() for i in range(hidden + 1)] for i in range(output)]
    net.append(o_layer)
    return net


def Act_sigmoid(x):  # 활성화 함수 - 시그모이드
    y = 1 / (1 + math.exp(-x))
    return y


def Act_relu(x):
    if x > 0:
        y = x
    else:
        y = 0
    return y


def Weight_summation(data, net, layer):
    # 입력값에 layer를 사용한 이유는 히든층에서의 웨이트 계산할 때는 [0]네트워크(웨이트)
    #  아웃층에서 웨이트 계산할 때는 [1]네트워크(웨이트) 사용
    numberOfinp = len(net[0][0]) - 1  # 만약 인풋이 두개면 2
    numberOfhid = len(net[0])  # 히든노드 두개면 2
    numberOfout = len(net[1])  # 아웃노드 두개면 2
    W_s = []  # 웨이트 써메이션 초기화

    if layer == 'H':  # 인풋- > '히든'레이어 갈 때
        for i in range(0, numberOfhid):
            h_w = 0
            h_w = h_w + (1 * net[0][i][numberOfinp])  # 바이어스와 웨이트의 곱
            for j in range(0, numberOfinp):
                h_w = h_w + (data[j] * net[0][i][j])
            W_s.append(h_w)
        W_s = [W_s]

    if layer == 'O':
        for i in range(0, numberOfout):
            o_w = 0
            o_w = o_w + (1 * net[1][i][numberOfhid])
            for j in range(0, numberOfhid):
                o_w = o_w + data[j] * net[1][i][j]  # 히든노드
            W_s.append(o_w)
        W_s = [W_s]  # [ [ ~~ ]]
    return W_s


def Forward_propagation(data, net):  # 순전파 진행하면서 인풋데이타, 인풋-히든 웨이트
    node = list()
    node.append(data)
    Ws1 = Weight_summation(data, net, 'H')  # [[ h1_1_before,  h1_2_before ]]
    # print('[[h1_1_before,  h1_2_before]] : ',Ws1,'\n')
    numberOfhid = len(net[0])  # 히든노드 두개면 2
    numberOfout = len(net[1])

    H1 = list()
    for i in range(0, numberOfhid):
        H1.append(Act_relu(Ws1[0][i]))
    # H1 = [ H1_1 H1_2 ~~~~]
    node.append(H1)

    Ws2 = Weight_summation(H1, net, 'O')  # [[ o1_1_before, o_2_before ]]
    # print('[[ o1_1_before, o_2_before ]] : ',Ws2,'\n')

    O1 = list()
    for i in range(0, numberOfout):
        O1.append(Act_relu(Ws2[0][i]))

    node.append(O1)

    # print("[[IN1,IN2, T], [H1, H2], [OUT1, OUT2]]:",node,'\n')
    return node


def Backward_propagation_relu(weight, dataset):  # 역전파
    numberOfout = len(weight[1])  # 아웃노드 두개면 2
    numberOfdata = len(dataset)
    numberOfhid = len(weight[0])
    numberOfinp = len(weight[0][0]) - 1

    c2 = list()
    h_layer = [[0 for i in range(numberOfinp + 1)] for i in range(numberOfhid)]
    c2.append(h_layer)
    o_layer = [[0 for i in range(numberOfhid + 1)] for i in range(numberOfout)]
    c2.append(o_layer)
    c2

    init_back = c2
    for Da in range(0, numberOfdata):
        Data = dataset[Da]
        forward = Forward_propagation(Data, weight)
        Input = forward[0]
        Hid = forward[1]
        Output = forward[2]

        table = []
        for i in range(0, numberOfout):
            if i == Data[numberOfinp]:
                table.append(1)
            else:
                table.append(0)

        # 아웃에서 히든으로 역전파 과정
        for i in range(0, numberOfout):
            out_before = weight[1][i][numberOfhid] * 1  # 바이어스에 대한 역전파 시작
            for j in range(0, numberOfhid):
                out_before = out_before + weight[1][i][j] * Hid[j]
            if out_before > 0:
                g_prime_out_before = 1
            else:
                g_prime_out_before = 0

            init_back[1][i][numberOfhid] = init_back[1][i][numberOfhid] + \
                                           (2 * (Output[i] - table[i]) * g_prime_out_before * 1) * (1 / numberOfout)

            for j in range(0, numberOfhid):
                init_back[1][i][j] = init_back[1][i][j] * 1 + \
                                     (2 * (Output[i] - table[i]) * g_prime_out_before * Hid[j]) * (1 / numberOfout)

        # 히든에서 인풋으로 역전파 과정
        for i in range(0, numberOfhid):
            h_before = weight[0][i][numberOfinp] * 1
            for l in range(0, numberOfinp):
                h_before = h_before + weight[0][i][l] * Input[l]

            if h_before > 0:
                g_prime_h_before = 1
            else:
                g_prime_h_before = 0

            for m in range(0, numberOfout):
                out_before = weight[1][m][numberOfhid] * 1  # out_before의 초기값은 바이어스에 대한 웨이트
                for k in range(0, numberOfhid):
                    out_before = out_before + weight[1][m][k] * Hid[k]  # out1_before -> out2_before

                # 여기까지 이상없음
                if out_before > 0:
                    g_prime_out_before = 1
                else:
                    g_prime_out_before = 0

                init_back[0][i][numberOfinp] = init_back[0][i][numberOfinp] + \
                                               2 * ((Output[m] - table[m]) * g_prime_out_before * weight[1][m][i] \
                                                    * g_prime_h_before * 1) * (1 / numberOfout)  # 바이어스

                for p in range(0, numberOfinp):
                    init_back[0][i][p] = init_back[0][i][p] + \
                                         2 * ((Output[m] - table[m]) * g_prime_out_before * weight[1][m][i] \
                                              * g_prime_h_before * Input[p]) * (1 / numberOfout)

    for i in range(0, numberOfhid):
        for j in range(0, numberOfinp + 1):
            init_back[0][i][j] = init_back[0][i][j] / numberOfdata

    for i in range(0, numberOfout):
        for j in range(0, numberOfhid + 1):
            init_back[1][i][j] = init_back[1][i][j] / numberOfdata

    return init_back


def Weight_update(backpropa, Now_weight):
    numberOfout = len(Now_weight[1])  # 아웃노드 두개면 2
    numberOfhid = len(Now_weight[0])
    numberOfinp = len(Now_weight[0][0]) - 1

    New_weight = list()
    learning_rate = 0.01

    in_hid_w = Now_weight[0]
    hid_out_w = Now_weight[1]

    out_hid_back = backpropa[1]
    hid_in_back = backpropa[0]

    c2 = list()
    h_layer = [[0 for i in range(numberOfinp + 1)] for i in range(numberOfhid)]
    c2.append(h_layer)
    o_layer = [[0 for i in range(numberOfhid + 1)] for i in range(numberOfout)]
    c2.append(o_layer)

    # inp -> hid 업데이트
    for i in range(0, numberOfhid):
        c2[0][i][numberOfinp] = in_hid_w[i][numberOfinp] \
                                - (hid_in_back[i][numberOfinp] * learning_rate)
        for j in range(0, numberOfinp):
            c2[0][i][j] = in_hid_w[i][j] - (hid_in_back[i][j] * learning_rate)

    # hid -> out 업데이트
    for i in range(0, numberOfout):
        c2[1][i][numberOfhid] = hid_out_w[i][numberOfhid] \
                                - (out_hid_back[i][numberOfhid] * learning_rate)
        for j in range(0, numberOfhid):
            c2[1][i][j] = hid_out_w[i][j] - (out_hid_back[i][j] * learning_rate)

    return c2


def Loss_function(dataset, net):  # 손실함수 - MSE(평균 제곱 오차)
    numberOfdata = len(dataset)
    numberOfinp = len(net[0][0]) - 1
    numberOfout = len(net[1])
    mse = 0

    for j in range(0, numberOfdata):
        Data = dataset[j]
        table = []
        for i in range(0, numberOfout):
            if i == Data[numberOfinp]:
                table.append(1)
            else:
                table.append(0)

        Fpropa = Forward_propagation(Data, net)  # 아웃풋 구하기

        for j in range(0, numberOfout):
            mse = mse + (1 / numberOfout) * (Fpropa[2][j] - table[j]) ** 2

    mse = mse / numberOfdata
    return mse


def Epoch(dataset, net, N):  # N = 학습횟수

    updatedW = net

    for i in range(0, N):
        bp = Backward_propagation_relu(updatedW, dataset)
        updatedW = Weight_update(bp, updatedW)
        mse = Loss_function(dataset, updatedW)
        print(i + 1, '번 학습함, mse =', mse)
    print('최종 학습된 가중치:',updatedW)
    return updatedW


data = [[3.5064385449265267, 2.34547092892632525, 0], [4.384621956392097, 3.4530853889904205, 0],
        [4.841442919897487, 4.02507852317520154, 0], [3.5985868973088437, 4.1621314217538705, 0],
        [2.887219775424049, 3.31523082529190005, 0], [9.79822645535526, 1.1052409596099566, 1],
        [7.8261241795117422, 0.6711054766067182, 1], [2.5026163932400305, 5.800780055043912, 1],
        [5.032436157202415, 8.650625621472184, 1], [4.095084253434162, 7.69104329159447, 1]]
net = MLP2(2, 2, 2)

Epoch(data, net, 30000)
